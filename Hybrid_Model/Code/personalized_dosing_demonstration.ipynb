# %% [markdown]
# # Personalized Lorlatinib Dosing
#
# **Purpose:** Demonstrate that patients with different c_in values (CYP3A4 metabolizer phenotypes) can achieve similar PK profiles to the reference (c_in=1.0, 100mg QD) by adjusting the dosing regimen.
#
# **Author:** Generated for MetabolismProject_BasantaLab_Rotation_2025
# **Last Updated:** March 2026
#
# ---
#
# ## Overview
#
# This notebook demonstrates three personalized dosing strategies:
#
# 1. **Dose Adjustment:** Modulate dose while keeping interval constant to minimize difference between AUC of average metabolizer (c_in=1.0, 100mg QD) and of patient
# 2. **Frequency Adjustment:** Modulate dosing interval while keeping dose constant to minimize difference between AUC of average metabolizer (c_in=1.0, 100mg QD) and of patient
# 3. **Joint Adjustment:** Modulate both frequency and dose together to minimize difference between AUC, C$_{max}$, and C$_{min}$ of average metabolizer (c_in=1.0, 100mg QD) and of patient
#
# The components of the simulation are:
#
# 1. **Section 1:** Import packages.
# 2. **Section 2:** Define Hybrid PK model. This model class can simulate and return drug concentration over time in each compartment (depot, central, and peripheral) and clearance over time. The independent variables are dose, dose frequency, number of doses given, and c$_{in}$.
# 3. **Section 3:** Define helper functions. The calculate_final_metrics function calculates PK metrics at last dosing interval, even if simulation is cut off before dosing interval is complete. Note: It takes ~15 days to reach steady state.
#
# Each optimization strategy is attempted and visualized for a slow metabolizer (c_in=0.27) and a fast metabolizer (c_in=2.52). Visualizations include:
#
# 1. **Section 7:** Lorlatinib concentration vs. time for slow, average, and fast metabolizer. Simulated and plotted for 7 days and 15 days.
# 2. **Section 8:** Dose adjustment only and frequency adjustment only strategies. Lor conc vs time profiles for all 3 metabolizers adjusted vs unadjusted. Comparison of adjusted and unadjusted PK metrics for each strategy.

# %% [markdown]
# ## Experimental Notes
#
# ---
#
# ### Clinically Motivated Optimization
#
# The lower bound for C$_{min}$ was chosen to be 150 ng/mL. This choice was derived from the G1202R inhibition threshold reported in:
#
# *Chen J, et al. (2021) Lorlatinib Exposure-Response Analyses for Safety and Efficacy in a Phase I/II Trial to Support Benefit-Risk Assessment in Non-Small Cell Lung Cancer. Clin Pharmacol Ther. PMID: 33973232.*
#
# AUC and Cmax within 70–143% of reference the limits of available clinical evidence. It would also be worth noting that the exposure-response analysis found no statistically significant efficacy relationship with AUC or Cmax across the studied range, which itself suggests the window may be wider than 70–143% on the efficacy side — the upper bound is more likely constrained by toxicity (hypercholesterolemia, adverse events) than by a loss of efficacy.
#
#
# ### Steady-state PK Calculations
#
# At steady state, for a linear PK system: \
# *AUC_ss = Dose / CL_ss*
#
# In our model, CL_ss scales linearly with c_in: \
# *CL_ss = c_in × CL_max*
#
# ---

# %% [markdown]
# ## 1. Setup and Imports

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.optimize import minimize
from scipy.optimize import brentq
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# Global plot formatting
import matplotlib
matplotlib.rcParams.update({
    'font.family': 'Arial',
    'font.size': 18,
})

# %% [markdown]
# ## 2. PK Model Implementation
#
# The Hybrid Model combines:
# - Chen et al. (2021) 2-compartment structure with time-varying clearance
# - c_in personalization parameter for individual CYP3A4 activity
#
# ### Model Equation:
#
# $$CL(t, c_{in}) = c_{in} \times [CL_{initial} + (CL_{max} - CL_{initial}) \times (1 - e^{-t/\tau})]$$

# %%
class HybridModel:
    """
    Hybrid model: Chen et al. structure + c_in personalization.

    CL(t, c_in) = c_in × [CL_initial + (CL_max - CL_initial) × (1 - exp(-t/τ))]
    """

    def __init__(self, c_in=1.0):
        # Parameterization from Chen et al. (2021) 
        self.ka = 3.113          # h^-1, absorption rate constant
        self.CL_initial = 9.035  # L/h, initial clearance
        self.CL_max = 14.472     # L/h, steady-state clearance
        self.tau = 50.251        # h, induction time constant (= 1/IND = 1/0.0199)
        self.V2 = 120.511        # L, central volume of distribution
        self.V3 = 154.905        # L, peripheral volume of distribution
        self.Q = 22.002          # L/h, inter-compartmental clearance
        self.F = 0.759           # bioavailability

        self.c_in = c_in

    def clearance(self, t):
        """Time-varying clearance personalized by c_in."""
        induction_factor = 1 - np.exp(-t / self.tau)
        CL_t = self.CL_initial + (self.CL_max - self.CL_initial) * induction_factor
        return self.c_in * CL_t

    def ode_system(self, y, t):
        A_depot, A_central, A_peripheral = y
        CL_t = self.clearance(t)

        dA_depot = -self.ka * A_depot
        dA_central = (self.ka * A_depot
                     - (CL_t / self.V2) * A_central
                     - (self.Q / self.V2) * A_central
                     + (self.Q / self.V3) * A_peripheral)
        dA_peripheral = (self.Q / self.V2) * A_central - (self.Q / self.V3) * A_peripheral

        return [dA_depot, dA_central, dA_peripheral]

    def simulate_multiple_doses(self, dose_mg=100.0, n_doses=15, dosing_interval=24.0, n_points=5000):
        """Simulate multiple dose PK profile."""
        duration_hours = n_doses * dosing_interval + 24
        dose_ug = dose_mg * 1000 * self.F

        t = np.linspace(0, duration_hours, n_points)

        y0 = [0.0, 0.0, 0.0]
        dose_times = [i * dosing_interval for i in range(n_doses)]

        t_segments = []
        solution_segments = []
        current_state = y0
        t_start = 0

        for dose_idx in range(n_doses):
            if dose_idx < n_doses - 1:
                t_end = dose_times[dose_idx + 1]
            else:
                t_end = duration_hours

            t_segment = t[(t >= t_start) & (t < t_end)]
            if len(t_segment) == 0:
                continue

            # Add dose to depot
            current_state[0] += dose_ug

            solution_segment = odeint(self.ode_system, current_state, t_segment)
            t_segments.extend(t_segment)
            solution_segments.append(solution_segment)

            if len(solution_segment) > 0:
                current_state = solution_segment[-1, :]
            t_start = t_end

        solution_full = np.vstack(solution_segments)
        A_central = solution_full[:, 1]
        C_central = (A_central / self.V2) 

        return {'time': np.array(t_segments), 'C_central': C_central, 'dose_times': dose_times}

print("✓ HybridModel class defined")

# %% [markdown]
# ## 3. Helper Functions

# %%
def calculate_final_metrics(simulation, dosing_interval=24.0):
    """Calculate PK metrics at last dosing interval."""
    t = simulation['time']
    C = simulation['C_central']

    # Use the actual last dose time to define the final interval
    if 'dose_times' in simulation:
        t_last_dose = simulation['dose_times'][-1]
    else:
        # Fallback if dose_times not available
        t_last_dose = t[-1] - dosing_interval - 24

    mask = (t >= t_last_dose) & (t < t_last_dose + dosing_interval)

    t_f = t[mask]
    C_f = C[mask]

    Cmax_f = np.max(C_f)
    Cmin_f = np.min(C_f)
    AUC_f = np.trapezoid(C_f, t_f - t_f[0]) #y=array of conc in final interval, dx=array of times in final interval 

    return {
        'Cmax_f': Cmax_f,
        'Cmin_f': Cmin_f,
        'AUC_f': AUC_f,
        'Cavg_f': AUC_f / dosing_interval
    }

print("\u2713 calculate_final_metrics defined")

# %%
def find_steady_state(c_in, dose_mg=100.0, dosing_interval=24.0,
                       tol=0.01, min_doses=10, max_doses=300):
    """
    Return the number of doses required to reach steady state for a given c_in.

    Simulates repeated dosing in blocks of 5 until the AUC of the last
    interval changes by less than tol relative to the previous check.
    Because CL(t) does not depend on dose, any reference dose_mg can be used.

    Parameters
    ----------
    c_in          : float — CYP3A4 activity parameter
    dose_mg       : float — reference dose in mg (default 100 mg)
    dosing_interval : float — dosing interval in hours (default 24 h)
    tol           : float — relative AUC convergence threshold (default 1 %)
    min_doses     : int   — minimum doses before convergence is checked
    max_doses     : int   — hard cap to prevent runaway loops

    Returns
    -------
    n_doses : int — number of doses at which steady state is declared
    """
    model = HybridModel(c_in=c_in)
    prev_auc = None

    for n in range(min_doses, max_doses + 1, 5):
        sim = model.simulate_multiple_doses(
            dose_mg=dose_mg, n_doses=n, dosing_interval=dosing_interval
        )
        auc = calculate_final_metrics(sim, dosing_interval)['AUC_f']

        if prev_auc is not None and abs(auc - prev_auc) / prev_auc < tol:
            return n

        prev_auc = auc

    return max_doses  # fallback if convergence not reached

print('\u2713 find_steady_state defined')

# %% [markdown]
# What would happen if the simulation ran much longer than the final dose interval?

# %%
def find_optimal_dose(c_in_target, target_metrics, dosing_interval=24.0):
    """
    Find optimal dose for a given c_in to match target metrics.

    Parameters:
    -----------
    c_in_target : float
        The c_in value for this patient
    target_metrics : dict
        Target PK metrics to match (from reference c_in=1.0)
    dosing_interval : float
        Dosing interval in hours

    Returns:
    --------
    optimal_dose : float
        Dose in mg that matches target metrics
    """
    n_doses = find_steady_state(c_in_target, dosing_interval=dosing_interval)

    # Scale initial guess and upper bound with c_in so the optimizer starts
    # close to the expected optimum (optimal dose ∝ c_in in linear PK).
    dose_init  = 100.0 * c_in_target
    dose_upper = max(600.0, 200.0 * c_in_target)

    def objective(dose):
        model = HybridModel(c_in=c_in_target)
        sim = model.simulate_multiple_doses(
            dose_mg=dose[0], n_doses=n_doses, dosing_interval=dosing_interval
        )
        metrics = calculate_final_metrics(sim, dosing_interval)
        # Relative squared error keeps the objective O(1) regardless of AUC scale,
        # giving L-BFGS-B reliable gradient estimates across all c_in values.
        error = ((metrics['AUC_f'] - target_metrics['AUC_f']) / target_metrics['AUC_f'])**2
        return error

    result = minimize(objective, x0=[dose_init],
                      bounds=[(10.0, dose_upper)], method='L-BFGS-B')
    return result.x[0]

print('\u2713 find_optimal_dose defined')

# %%
def find_optimal_interval(c_in_target, target_metrics, dose_mg=100.0):
    """
    Find optimal dosing interval for a given c_in to match target Cavg.

    At steady state, AUC per interval = F*dose/CL (independent of tau), so
    Cavg = AUC/tau is strictly monotone decreasing. brentq finds the unique
    root of Cavg(tau) - target_Cavg = 0, which is more robust than a
    gradient-based optimizer on this inherently 1-D monotone problem.

    Parameters:
    -----------
    c_in_target : float
    target_metrics : dict
    dose_mg : float — fixed dose in mg

    Returns:
    --------
    optimal_interval : float — dosing interval in hours
    """
    target_cavg = target_metrics['Cavg_f']

    def cavg_at_tau(tau):
        # Mirror section 16 sweep: enough doses to cover ~500 h so induction
        # (tau_ind = 50.25 h) is complete at every candidate interval.
        n_doses = max(20, int(500 / tau))
        model = HybridModel(c_in=c_in_target)
        sim = model.simulate_multiple_doses(
            dose_mg=dose_mg, n_doses=n_doses, dosing_interval=tau
        )
        return calculate_final_metrics(sim, dosing_interval=tau)['Cavg_f']

    tau_min, tau_max = 1.0, 96.0

    cavg_lo = cavg_at_tau(tau_min)   # high Cavg — short interval
    cavg_hi = cavg_at_tau(tau_max)   # low  Cavg — long  interval

    # If target falls outside the achievable range, return the nearest bound.
    if cavg_lo < target_cavg:
        return tau_min
    if cavg_hi > target_cavg:
        return tau_max

    optimal_tau = brentq(
        lambda tau: cavg_at_tau(tau) - target_cavg,
        tau_min, tau_max,
        xtol=0.05   # converge to within 3 minutes — sufficient for dosing
    )
    return optimal_tau

print('\u2713 find_optimal_interval defined')

# %% [markdown]
# ## 4. Reference Patient Simulation
#
# Establish baseline PK for average metabolizer (c_in = 1.0, 100mg QD)

# %%
print("="*80)
print("PERSONALIZED DOSING DEMONSTRATION")
print("Hybrid Model (Chen + c_in)")
print("="*80)
print()
print("Calculating personalized dosing strategies...")
print("="*80)

# Reference: Average metabolizer (c_in = 1.0, 100mg QD)
print("\n1. Reference Patient (Average Metabolizer):")
print("   c_in = 1.0, Dose = 100 mg QD")
model_ref = HybridModel(c_in=1.0)
sim_ref = model_ref.simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
metrics_ref = calculate_final_metrics(sim_ref, dosing_interval=24)

print(f"   Cmax_ss = {metrics_ref['Cmax_f']:.1f} ng/mL")
print(f"   Cmin_ss = {metrics_ref['Cmin_f']:.1f} ng/mL")
print(f"   AUC_ss  = {metrics_ref['AUC_f']:.1f} ng·h/mL")
print(f"   Cavg_ss = {metrics_ref['Cavg_f']:.1f} ng/mL")

# %% [markdown]
# ## 5. Fast Metabolizer Dosing Strategies
#
# Patient with c_in = 2.52 (rapid metabolizer)

# %%
# Reference: Fast Metabolizer (c_in = 2.52, 100mg QD)
print("\n1. Reference Patient (Fast Metabolizer):")
print("   c_in = 2.52, Dose = 100 mg QD")
model_ref_fast = HybridModel(c_in=10)
sim_ref_fast = model_ref_fast.simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
metrics_ref_fast = calculate_final_metrics(sim_ref_fast, dosing_interval=24)

print(f"   Cmax_ss = {metrics_ref_fast['Cmax_f']:.1f} ng/mL")
print(f"   Cmin_ss = {metrics_ref_fast['Cmin_f']:.1f} ng/mL")
print(f"   AUC_ss  = {metrics_ref_fast['AUC_f']:.1f} ng·h/mL")
print(f"   Cavg_ss = {metrics_ref_fast['Cavg_f']:.1f} ng/mL")

c_in_fast = 10

# Strategy 1: Increase dose, keep interval
dose_fast = find_optimal_dose(c_in_fast, metrics_ref, dosing_interval=24)
print(f"   Strategy 1 - Dose adjustment: {dose_fast:.1f} mg QD")
model_fast_dose = HybridModel(c_in=c_in_fast)
sim_fast_dose = model_fast_dose.simulate_multiple_doses(dose_mg=dose_fast, n_doses=18, dosing_interval=24)
metrics_fast_dose = calculate_final_metrics(sim_fast_dose, dosing_interval=24)
print(f"      Cmax_ss = {metrics_fast_dose['Cmax_f']:.1f} ng/mL")
print(f"      Cmin_ss = {metrics_fast_dose['Cmin_f']:.1f} ng/mL")
print(f"      AUC_ss  = {metrics_fast_dose['AUC_f']:.1f} ng·h/mL")

# Strategy 1A: Clinically feasible interval (Q12h)
#dose_fast_clinical = find_optimal_dose(c_in_fast, metrics_ref, dosing_interval=12)
#print(f"   Strategy 1A - Clinical Interval: {dose_fast_clinical:.1f} mg QD")
#model_fast_dose_clinical = HybridModel(c_in=c_in_fast)
#sim_fast_dose_clinical = model_fast_dose_clinical.simulate_multiple_doses(dose_mg=dose_fast, n_doses=18, dosing_interval=12)
#metrics_fast_dose_clinical = calculate_final_metrics(sim_fast_dose_clinical, dosing_interval=12)
#print(f"      Cmax_ss = {metrics_fast_dose_clinical['Cmax_f']:.1f} ng/mL")
#print(f"      Cmin_ss = {metrics_fast_dose_clinical['Cmin_f']:.1f} ng/mL")
#print(f"      AUC_ss  = {metrics_fast_dose_clinical['AUC_f']:.1f} ng·h/mL")
#print(f"      Cavg_f = {metrics_fast_dose_clinical['Cavg_f']:.1f} ng/mL (target: {metrics_ref['Cavg_f']:.1f})")

# Strategy 2: Keep dose, increase frequency
#interval_fast = find_optimal_interval(c_in_fast, metrics_ref, dose_mg=100)
#print(f"   Strategy 2 - Frequency adjustment: 100 mg every {interval_fast:.1f} h (Q{interval_fast:.0f}h)")
#duration_fast = max(480, interval_fast * 20)
#n_doses_fast = int(duration_fast / interval_fast)
#sim_fast_freq = model_fast_dose.simulate_multiple_doses(dose_mg=100, n_doses=n_doses_fast, dosing_interval=interval_fast)
#metrics_fast_freq = calculate_final_metrics(sim_fast_freq, dosing_interval=interval_fast)
#print(f"      Cmax_f = {metrics_fast_freq['Cmax_f']:.1f} ng/mL")
#print(f"      Cmin_f = {metrics_fast_freq['Cmin_f']:.1f} ng/mL")
#print(f"      AUC_f  = {metrics_fast_freq['AUC_f']:.1f} ng·h/mL")
#print(f"      Cavg_f = {metrics_fast_freq['Cavg_f']:.1f} ng/mL (target: {metrics_ref['Cavg_f']:.1f})")

# %%
c_in_fast = 10

# Strategy 1: Increase dose, keep interval
#dose_fast = find_optimal_dose(c_in_fast, metrics_ref, dosing_interval=24)
#print(f"   Strategy 1 - Dose adjustment: {dose_fast:.1f} mg QD")
#model_fast_dose = HybridModel(c_in=c_in_fast)
#sim_fast_dose = model_fast_dose.simulate_multiple_doses(dose_mg=dose_fast, n_doses=18, dosing_interval=24)
#metrics_fast_dose = calculate_final_metrics(sim_fast_dose, dosing_interval=24)
#print(f"      Cmax_ss = {metrics_fast_dose['Cmax_f']:.1f} ng/mL")
#print(f"      Cmin_ss = {metrics_fast_dose['Cmin_f']:.1f} ng/mL")
#print(f"      AUC_ss  = {metrics_fast_dose['AUC_f']:.1f} ng·h/mL")

# Strategy 2: Keep dose, increase frequency
interval_fast = find_optimal_interval(c_in_fast, metrics_ref, dose_mg=100)
print(f"   Strategy 2 - Frequency adjustment: 100 mg every {interval_fast:.1f} h (Q{interval_fast:.0f}h)")
n_doses_fast = max(20, int(500 / interval_fast))  # matches section 16 sweep formula
model_fast_freq = HybridModel(c_in=c_in_fast)
sim_fast_freq = model_fast_freq.simulate_multiple_doses(dose_mg=100, n_doses=n_doses_fast, dosing_interval=interval_fast)
metrics_fast_freq = calculate_final_metrics(sim_fast_freq, dosing_interval=interval_fast)
print(f"      Cmax_f = {metrics_fast_freq['Cmax_f']:.1f} ng/mL")
print(f"      Cmin_f = {metrics_fast_freq['Cmin_f']:.1f} ng/mL")
print(f"      AUC_f  = {metrics_fast_freq['AUC_f']:.1f} ng·h/mL")
print(f"      Cavg_f = {metrics_fast_freq['Cavg_f']:.1f} ng/mL (target: {metrics_ref['Cavg_f']:.1f})")

# %% [markdown]
# ## 6. Slow Metabolizer Dosing Strategies
#
# Patient with c_in = 0.27 (poor metabolizer)

# %%
# Reference: Slow Metabolizer (c_in = 0.27, 100mg QD)
print("\n1. Reference Patient (Slow Metabolizer):")
print("   c_in = 0.27, Dose = 100 mg QD")
model_ref_slow = HybridModel(c_in=0.27)
sim_ref_slow = model_ref_slow.simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
metrics_ref_slow = calculate_final_metrics(sim_ref_slow, dosing_interval=24)

print(f"   Cmax_ss = {metrics_ref_slow['Cmax_f']:.1f} ng/mL")
print(f"   Cmin_ss = {metrics_ref_slow['Cmin_f']:.1f} ng/mL")
print(f"   AUC_ss  = {metrics_ref_slow['AUC_f']:.1f} ng·h/mL")
print(f"   Cavg_ss = {metrics_ref_slow['Cavg_f']:.1f} ng/mL")
c_in_slow = 0.27

# Strategy 1: Decrease dose, keep interval
dose_slow = find_optimal_dose(c_in_slow, metrics_ref, dosing_interval=24)
print(f"   Strategy 1 - Dose adjustment: {dose_slow:.1f} mg QD")
model_slow_dose = HybridModel(c_in=c_in_slow)
sim_slow_dose = model_slow_dose.simulate_multiple_doses(dose_mg=dose_slow, n_doses=18, dosing_interval=24)
metrics_slow_dose = calculate_final_metrics(sim_slow_dose, dosing_interval=24)
print(f"      Cmax_f = {metrics_slow_dose['Cmax_f']:.1f} ng/mL")
print(f"      Cmin_f = {metrics_slow_dose['Cmin_f']:.1f} ng/mL")
print(f"      AUC_f  = {metrics_slow_dose['AUC_f']:.1f} ng·h/mL")

# Strategy 2: Keep dose, decrease frequency
interval_slow = find_optimal_interval(c_in_slow, metrics_ref, dose_mg=100)
print(f"   Strategy 2 - Frequency adjustment: 100 mg every {interval_slow:.1f} h (Q{interval_slow:.0f}h)")
duration_slow = max(480, interval_slow * 20)
n_doses_slow = int(duration_slow / interval_slow)
sim_slow_freq = model_slow_dose.simulate_multiple_doses(dose_mg=100, n_doses=n_doses_slow, dosing_interval=interval_slow)
metrics_slow_freq = calculate_final_metrics(sim_slow_freq, dosing_interval=interval_slow)
print(f"      Cmax_f = {metrics_slow_freq['Cmax_f']:.1f} ng/mL")
print(f"      Cmin_f = {metrics_slow_freq['Cmin_f']:.1f} ng/mL")
print(f"      AUC_f  = {metrics_slow_freq['AUC_f']:.1f} ng·h/mL")
print(f"      Cavg_f = {metrics_slow_freq['Cavg_f']:.1f} ng/mL (target: {metrics_ref['Cavg_f']:.1f})")

print("\n" + "="*80)

# %% [markdown]
# ## Dose Requirements Across c_in Range
#
# Calculate optimal doses for a range of c_in values

# %%
c_in_range = np.linspace(0.3, 2.5, 20)
optimal_doses = []

print("Calculating optimal doses across c_in range...")
for i, c_in_val in enumerate(c_in_range):
    dose = find_optimal_dose(c_in_val, metrics_ref, dosing_interval=24)
    optimal_doses.append(dose)
    if (i+1) % 5 == 0:
        print(f"  Progress: {i+1}/{len(c_in_range)}")

print("✓ Dose optimization complete")

# %% [markdown]
# ## 7. Plasma Concentration Profiles vs Time
# ### Visualized for Slow, Average, and Fast Metabolizers
#
# Simulate 100 mg QD for the first 7 days. Note: This is not sufficient to reach steady-state, which takes ~15 days. An additional 15-day simulation is included below.

# %%
#Define Representative Metabolizers for Simulation 
PHENO_3 = [
    (0.27, 'Slow (c_in=0.27)', dict(color='gold', linewidth=4, alpha=0.9)),
    (1.00, 'Average (c_in=1.0)', dict(color='darkorange', linewidth=4, alpha=1.0)),
    (2.52, 'Fast (c_in=2.52)', dict(color='darkred', linewidth=4, alpha=0.9)),
]

#Initialize Figure
fig_multi, ax_multi = plt.subplots(figsize=(10, 5))

for c_in_val, label, kwargs in PHENO_3:
    sim = HybridModel(c_in=c_in_val).simulate_multiple_doses(dose_mg=100, n_doses=7, dosing_interval=24)
    t_days = sim['time'] / 24
    ax_multi.plot(t_days, sim['C_central'], label=label, **kwargs)

#Plot steady-state Cmax and Cmin reference lines for average metabolizer (c_in = 1.0)
#ax_multi.axhline(metrics_ref['Cmax_f'], color='darkorange', ls='--', lw=1.5, alpha=0.8,
 #                label=f'Avg C$_{{max}}$ ({metrics_ref["Cmax_f"]:.0f} ng/mL)')
#ax_multi.axhline(metrics_ref['Cmin_f'], color='darkorange', ls=':',  lw=1.5, alpha=0.8,
 #                label=f'Avg C$_{{min}}$ ({metrics_ref["Cmin_f"]:.0f} ng/mL)')

ax_multi.set_xlabel('Time (days)', fontsize=18) 
ax_multi.set_ylabel('lorlatinib (ng/mL)', fontsize=18) 
#ax_multi.set_title('Lorlatinib vs Time of Different Metabolizers',fontsize=18, fontweight='bold')
ax_multi.set_xlim(0, 7)
ax_multi.set_xticks([0, 1, 2, 3, 4, 5, 6, 7], [0, 1, 2, 3, 4, 5, 6, 7])
ax_multi.spines['top'].set_visible(False)
ax_multi.spines['right'].set_visible(False)
#ax_multi.grid(True, alpha=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, loc = 'best', bbox_to_anchor=(1.05,0.95), borderaxespad=0,frameon=False)

save_path = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/Fig1B.pdf')
#plt.savefig(save_path, dpi=300, bbox_inches='tight', transparent = True)

plt.tight_layout()
plt.show()

# %%
#Simulate and Visualize to Steady-state (15 days)

#Define Representative Metabolizers for Simulation 
PHENO_3 = [
    (0.27, 'Slow (c_in=0.27)', dict(color='gold', linewidth=4, alpha=0.9)),
    (1.00, 'Average (c_in=1.0)', dict(color='darkorange', linewidth=4, alpha=1.0)),
    (2.52, 'Fast (c_in=2.52)', dict(color='darkred', linewidth=4, alpha=0.9)),
]

#Initialize Figure
fig_multi, ax_multi = plt.subplots(figsize=(13, 8))

for c_in_val, label, kwargs in PHENO_3:
    sim = HybridModel(c_in=c_in_val).simulate_multiple_doses(dose_mg=100, n_doses=15, dosing_interval=24)
    t_days = sim['time'] / 24
    ax_multi.plot(t_days, sim['C_central'], label=label, **kwargs)

#Plot steady-state Cmax and Cmin reference lines for average metabolizer (c_in = 1.0)
ax_multi.axhline(metrics_ref['Cmax_f'], color='darkorange', ls='--', lw=1.5, alpha=0.8,
                 label=f'Avg C$_{{max}}$ ({metrics_ref["Cmax_f"]:.0f} ng/mL)')
ax_multi.axhline(metrics_ref['Cmin_f'], color='darkorange', ls=':',  lw=1.5, alpha=0.8,
                 label=f'Avg C$_{{min}}$ ({metrics_ref["Cmin_f"]:.0f} ng/mL)')

ax_multi.set_xlabel('Time (days)', fontsize=18) 
ax_multi.set_ylabel('lorlatinib (ng/mL)', fontsize=18) 
#ax_multi.set_title('Lorlatinib vs Time of Different Metabolizers',fontsize=18, fontweight='bold')
ax_multi.set_xlim(0, 15)
ax_multi.spines['top'].set_visible(False)
ax_multi.spines['right'].set_visible(False)
#ax_multi.grid(True, alpha=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, loc = 'best', bbox_to_anchor=(1.05,0.95), borderaxespad=0,frameon=False)

save_path = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/Fig1B.pdf')
#plt.savefig(save_path, dpi=300, bbox_inches='tight', transparent = True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Section 7 Notes
#
# Why does the slow metabolizer take longer to reach steady-state?

# %% [markdown]
# ## 8. Dose or Freq Adjustment Visualizations

# %%
#Simulate baseline profiles (100 mg QD) for fast and slow metabolizers
sim_fast_unadj = HybridModel(c_in=10).simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
sim_slow_unadj = HybridModel(c_in=c_in_slow).simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)

#Initialize Figure
fig = plt.figure(figsize=(26, 9))
#fig = plt.figure(figsize=(18, 9))
gs = fig.add_gridspec(2, 3, hspace=0.45, wspace=1.2)
plt.rcParams['axes.titlepad'] = 12

# =========================================================================
# Row 1: Dose Adjustment Strategy
# =========================================================================


# =========================================================================
# Panel 1A: Fast metabolizer - dose adjustment
# =========================================================================
ax1 = fig.add_subplot(gs[0, 0])

#Time from hours to days 
t_ref_days = sim_ref['time'] / 24 
t_fast_unadj_days = sim_fast_unadj['time'] / 24
t_fast_days = sim_fast_dose['time'] / 24

#Plot Plasma Conc Profiles 
ax1.plot(t_ref_days, sim_ref['C_central'], 'darkorange', linewidth=4,
         label='c$_{in}$=1, 100mg QD') #Av Metabolizer, SOC
ax1.plot(t_fast_unadj_days, sim_fast_unadj['C_central'], '-', color='darkred', linewidth=2, alpha=0.9,
         label='c$_{in}$=10, 100mg QD') #Fast Metabolizer, SOC
ax1.plot(t_fast_days, sim_fast_dose['C_central'], '-',color = 'blue', linewidth = 2, alpha = 0.7,
         label='c$_{in}$=10, 1000mg QD') #Fast Metabolizer, Optimized Dose 

#ax1.set_title('A. Dose Adjustment', fontsize=18, fontweight='bold')
ax1.set_xlabel('Time (days)', fontsize=18)
ax1.set_ylabel('lorlatinib (ng/mL)', fontsize=18) 
ax1.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
#ax1.grid(True, alpha=0.3)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xlim(13, 18)
ax1.set_ylim(0, 3500)

# =========================================================================
# Panel 1B: Slow metabolizer - dose adjustment
# =========================================================================

ax2 = fig.add_subplot(gs[0, 1])

#Time from hours to days 
t_slow_unadj_days = sim_slow_unadj['time'] / 24
t_slow_days = sim_slow_dose['time'] / 24

#Plot Plasma Conc Profiles 
ax2.plot(t_ref_days, sim_ref['C_central'], 'darkorange', linewidth=4,
         label='c$_{in}$=1, 100mg QD') #Av Metabolizer, SOC
ax2.plot(t_slow_unadj_days, sim_slow_unadj['C_central'], '-', color='gold', linewidth=2, alpha=0.9,
         label='c$_{in}$=0.27, 100mg QD') #Slow Metabolizer, SOC
ax2.plot(t_slow_days, sim_slow_dose['C_central'], 'g-', linewidth=2,
         label='c$_{in}$=0.27, 27mg QD') #Slow Metabolizer, Optimal Dose 

#ax2.set_title('B. Dose Adjustment', fontsize=18, fontweight='bold')
ax2.set_xlabel('Time (days)', fontsize=18)
ax2.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
#ax2.grid(True, alpha=0.3)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax2.set_xlim(13, 18)
ax2.set_ylim(0, 1200)

# =========================================================================
# Panel 1C: Comparison of steady-state PK metrics (dose adjustment)
# =========================================================================

ax3 = fig.add_subplot(gs[0, 2])

#Get SS PK Metrics 
metrics_names = ['AUC_f', 'Cmax_f', 'Cmin_f']
ref_vals = [metrics_ref[m] for m in metrics_names]
fast_vals = [metrics_fast_dose[m] for m in metrics_names]
slow_vals = [metrics_slow_dose[m] for m in metrics_names]

#PK Metrics to Percent of SOC 
ref_normalized = [100] * 3 #[100,100,100], not multiplication
fast_normalized = [(f/r)*100 for f, r in zip(fast_vals, ref_vals)]
slow_normalized = [(s/r)*100 for s, r in zip(slow_vals, ref_vals)]

x = np.arange(3)
width = 0.25

#Plot PK Percent of SOC 
ax3.bar(x - width, ref_normalized, width, label='c$_{in}$=1, 100mg QD', color = 'darkorange')
ax3.bar(x, fast_normalized, width, label='c$_{in}$=10, 1000mg QD', color='blue', alpha=0.7)
#ax3.bar(x + width, slow_normalized, width, label='c$_{in}$=0.27, 27mg QD', color='g')

#Plot 10% of SOC Interval 
ax3.axhline(100, color='black', linestyle='-', linewidth=1.5)
ax3.axhline(90, color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax3.axhline(110, color='gray', linestyle='--', linewidth=1, alpha=0.5)
ax3.axhspan(90, 110, alpha=0.2, color='green', label='\u00b110% Target Value')  

#ax3.set_title('C. PK Parameters', fontsize=18, fontweight='bold')
ax3.set_xticks(x)
ax3.set_xticklabels(['AUC', 'C$_{max}$', 'C$_{min}$'], fontsize=18)
ax3.set_ylabel('% of SOC', fontsize=18)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)

all_vals = ref_normalized + fast_normalized + slow_normalized #Concatenate list, not add
ax3.set_ylim(min(all_vals) * 0.90, max(all_vals) *  1.10)

#print(f'Fast c_in={c_in_fast}')
#print(f'Fast Dose Adjustment = {dose_fast:.0f} mg QD')
#print(f'Slow c_in={c_in_slow}')
#print(f'Slow Dose Adjustment = {dose_slow:.0f} mg QD')

print(f'Fast %SOC AUC = {fast_normalized[0]} %')
print(f'Fast %SOC Cmax = {fast_normalized[1]} %')
print(f'Fast %SOC Cmin = {fast_normalized[2]} %')

print(f'Slow %SOC AUC = {slow_normalized[0]} %')
print(f'Slow %SOC Cmax = {slow_normalized[1]} %')
print(f'Slow %SOC Cmin = {slow_normalized[2]} %')

# %%
# =========================================================================
# Row 2: Frequency Adjustment Strategy
# =========================================================================


# =========================================================================
# Panel 2D: Fast metabolizer - frequency adjustment
# =========================================================================
ax4 = fig.add_subplot(gs[1, 0])

#Time from hours to days 
t_fast_freq_days = sim_fast_freq['time'] / 24

#Plot Plasma Conc Profiles
ax4.plot(t_ref_days, sim_ref['C_central'], 'darkorange', linewidth=4,
         label='c$_{in}$=1, 100mg QD') #Av Metabolizer, SOC
ax4.plot(t_fast_unadj_days, sim_fast_unadj['C_central'], '-', color='darkred', linewidth=2, alpha=0.9,
         label='c$_{in}$=10, 100mg QD') #Fast Metabolizer, SOC
ax4.plot(t_fast_freq_days, sim_fast_freq['C_central'], '-', color = 'blue', linewidth = 2, alpha = 0.7,
         label=f'c$_{{in}}$=10, 100mg Q{interval_fast:.1f}h') #Fast Metabolizer, Optimal Freq 

#ax4.set_title('D. Frequency Adjustment', fontsize=18, fontweight='bold')
ax4.set_xlabel('Time (days)', fontsize=18)
ax4.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax4.set_xlim(16, 18)
ax4.set_ylim(0, 700)
ax4.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
#ax4.grid(True, alpha=0.3)
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)

# =========================================================================
# Panel 2E: Slow metabolizer - frequency adjustment
# =========================================================================

ax5 = fig.add_subplot(gs[1, 1])

#Time from hours to days 
t_slow_freq_days = sim_slow_freq['time'] / 24

#Plot Plasma Conc Profiles
ax5.plot(t_ref_days, sim_ref['C_central'], 'darkorange', linewidth=4,
         label='c$_{in}$=1, 100mg QD') #Av Metabolizer, SOC
ax5.plot(t_slow_unadj_days, sim_slow_unadj['C_central'], '-', color='gold', linewidth=2, alpha=0.9,
         label='c$_{in}$=0.27, 100mg QD') #Slow Metabolizer, SOC
ax5.plot(t_slow_freq_days, sim_slow_freq['C_central'], 'g-', linewidth=2,
         label=f'c$_{{in}}$=0.27, 100mg Q{interval_slow:.1f}h') #Slow Metabolizer, Optimal Freq 

#ax5.set_title('E. Frequency Adjustment', fontsize=18, fontweight='bold')
ax5.set_xlabel('Time (days)', fontsize=18)
ax5.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax5.set_xlim(13, 18)
ax5.set_ylim(0, 1200)
ax5.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
#ax5.grid(True, alpha=0.3)
ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)

# =========================================================================
# Panel 2F: Comparison of steady-state PK metrics (frequency adjustment)
# =========================================================================
# AUC is normalized by dosing interval for a fair cross-interval comparison

ax6 = fig.add_subplot(gs[1, 2])

#Get SS PK Metrics 
metrics_names_f = ['Cavg_f', 'Cmax_f', 'Cmin_f']
ref_vals_f  = [metrics_ref[m]       for m in metrics_names_f]
fast_vals_f = [metrics_fast_freq[m] for m in metrics_names_f]
slow_vals_f = [metrics_slow_freq[m] for m in metrics_names_f]

#PK Metrics to Percent of SOC 
ref_norm_f  = [100] * 3
fast_norm_f = [(f/r)*100 for f, r in zip(fast_vals_f, ref_vals_f)]
slow_norm_f = [(s/r)*100 for s, r in zip(slow_vals_f, ref_vals_f)]

x_f6 = np.arange(3)
width_f6 = 0.25

#Plot PK Percent of SOC 
ax6.bar(x_f6 - width_f6, ref_norm_f,  width_f6, label='c$_{in}$=1, 100mg QD', color = 'darkorange')
#ax6.bar(x_f6, slow_norm_f, width_f6, label=f'c$_{{in}}$=0.27, 100mg Q{interval_slow:.1f}h', color='g')
ax6.bar(x_f6, fast_norm_f, width_f6, label=f'c$_{{in}}$=10, 100mg Q{interval_fast:.1f}h', color='blue', alpha=0.7)


#Plot 10% of SOC Interval 
ax6.axhline(100, color='black', linestyle='-',  linewidth=1.5)
ax6.axhline(90,  color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax6.axhline(110, color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax6.axhspan(90, 110, alpha=0.2, color='green', label='\u00b110% Target Value')  

ax6.set_ylabel('% of SOC', fontsize=18)
#ax6.set_title('F. PK Parameters', fontsize=18, fontweight = 'bold')
ax6.set_xticks(x_f6)
ax6.set_xticklabels(['AUC/\u03c4', 'C$_{max}$', 'C$_{min}$'], fontsize=18)
ax6.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
#ax6.grid(True, alpha=0.3, axis='y')
ax6.spines['top'].set_visible(False)
ax6.spines['right'].set_visible(False)

all_vals_f = ref_norm_f + fast_norm_f + slow_norm_f
ax6.set_ylim(min(all_vals_f) * 0.90, max(all_vals_f) * 1.10)

from IPython.display import display
fig.tight_layout()
display(fig)

# Save each panel individually
fig.canvas.draw()
base = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
        'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/')
panels = {
    'PanelA': ax1, 'PanelB': ax2, 'PanelC': ax3,
    'PanelD': ax4, 'PanelE': ax5, 'PanelF': ax6,
}
for name, ax in panels.items():
    extent = ax.get_tightbbox(fig.canvas.get_renderer()) \
               .transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(base + f'{name}.pdf', bbox_inches=extent, dpi=300)
print(f'\u2713 Saved: {base}')

#print(f'Fast c_in={c_in_fast}')
#print(f'Fast Freq Adjustment = {sim_fast_freq['time']:.0f} mg QD')
#print(f'Slow c_in={c_in_slow}')
#print(f'Slow Dose Adjustment = {dose_slow:.0f} mg QD')

print(f'Fast %SOC AUC/tau = {fast_norm_f[0]} %')
print(f'Fast %SOC Cmax = {fast_norm_f[1]} %')
print(f'Fast %SOC Cmin = {fast_norm_f[2]} %')

print(f'Slow %SOC AUC/tau = {slow_norm_f[0]} %')
print(f'Slow %SOC Cmax = {slow_norm_f[1]} %')
print(f'Slow %SOC Cmin = {slow_norm_f[2]} %')

# %%
# =========================================================================
# Alt Viz: Seperate Bar Graphs for Fast vs Slow PK Metrics 
# =========================================================================

fig_bar, axes_bar = plt.subplots(1, 2, figsize=(10.6, 3.7))
plt.rcParams['axes.titlepad'] = 12

metric_keys  = ['Cavg_f', 'Cmax_f', 'Cmin_f']
x_labels     = ['AUC', 'C$_{max}$', 'C$_{min}$']
x            = np.arange(3)
w            = 0.25

# =========================================================================
# Panel 1A: Fast metabolizer
# =========================================================================

ax_f = axes_bar[0]

#Get SS PK Metrics 
ref_vals_f   = [metrics_ref[k]       for k in metric_keys]
dose_vals_f  = [metrics_fast_dose[k] for k in metric_keys]
freq_vals_f  = [metrics_fast_freq[k] for k in metric_keys]

#PK Metrics to Percent of SOC 
ref_norm_f   = [100] * 3
dose_norm_f  = [(v/r)*100 for v, r in zip(dose_vals_f,  ref_vals_f)]
freq_norm_f  = [(v/r)*100 for v, r in zip(freq_vals_f,  ref_vals_f)]

#Plot PK Percent of SOC
ax_f.bar(x - w, ref_norm_f, w, label=f'c$_{{in}}$=1.0, 100 mg QD', color='darkorange')
ax_f.bar(x, dose_norm_f, w, label=f'c$_{{in}}$={c_in_fast}, {dose_fast:.0f} mg QD', color='blue', alpha=0.9)
#ax_f.bar(x + w, freq_norm_f, w, label=f'c$_{{in}}$={c_in_fast}, 100 mg Q{interval_fast:.0f}h', color='blue', alpha=0.6)

ax_f.axhline(100, color='black', ls='-',  lw=1.5)
ax_f.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')

#ax_f.set_title(f'A. Fast Metabolizer (c$_{{in}}$={c_in_fast})',fontsize=18, fontweight='bold')
ax_f.set_xticks(x)
ax_f.set_xticklabels(x_labels, fontsize=18)
ax_f.set_ylabel('% SOC', fontsize=18)
ax_f.legend(loc='upper left', fontsize=10, frameon=False)
#ax_f.grid(True, alpha=0.3, axis='y')
ax_f.spines['top'].set_visible(False)
ax_f.spines['right'].set_visible(False)

all_f = ref_norm_f + dose_norm_f + freq_norm_f
#ax_f.set_ylim(min(all_f) * 0.90, max(all_f) * 1.15)
ax_f.set_ylim(0,200)

# =========================================================================
# Panel 1B: Slow metabolizer
# =========================================================================

ax_s = axes_bar[1]

#Get SS PK Metrics 
ref_vals_s   = [metrics_ref[k]       for k in metric_keys]
dose_vals_s  = [metrics_slow_dose[k] for k in metric_keys]
freq_vals_s  = [metrics_slow_freq[k] for k in metric_keys]

#PK Metrics to Percent of SOC 
ref_norm_s   = [100] * 3
dose_norm_s  = [(v/r)*100 for v, r in zip(dose_vals_s, ref_vals_s)]
freq_norm_s  = [(v/r)*100 for v, r in zip(freq_vals_s, ref_vals_s)]

#Plot PK Percent of SOC
ax_s.bar(x - w,  ref_norm_s,  w, label=f'c$_{{in}}$=1.0,  100 mg QD', color='darkorange')
ax_s.bar(x, dose_norm_s, w, label=f'c$_{{in}}$={c_in_slow}, {dose_slow:.0f} mg QD', color='g', alpha=0.9)
#ax_s.bar(x + w,  freq_norm_s, w, label=f'c$_{{in}}$={c_in_slow}, 100 mg Q{interval_slow:.0f}h', color='g', alpha=0.6)

#Plot 10% of SOC Interval 
ax_s.axhline(100, color='black', ls='-',  lw=1.5)
ax_s.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')

#ax_s.set_title(f'B. Slow Metabolizer (c$_{{in}}$={c_in_slow})',fontsize=18, fontweight='bold')
ax_s.set_xticks(x)
ax_s.set_xticklabels(x_labels, fontsize=18)
ax_s.set_ylabel('% SOC', fontsize=18)
ax_s.legend(loc='upper left', fontsize=10, frameon=False)
#ax_s.grid(True, alpha=0.3, axis='y')
ax_s.spines['top'].set_visible(False)
ax_s.spines['right'].set_visible(False)

all_s = ref_norm_s + dose_norm_s + freq_norm_s
#ax_s.set_ylim(min(all_s) * 0.90, max(all_s) * 1.15)
ax_s.set_ylim(0,200)

plt.tight_layout()
plt.show()

out_bar = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
           'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
           'PK_Bar_Graph_Split.pdf')
#fig_bar.savefig(out_bar, dpi=300, bbox_inches='tight')

# Save each panel individually
fig_bar.canvas.draw()
base = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
        'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/')
panels = {
    'Fig2C': ax_f, 'Fig2F': ax_s
}
for name, ax in panels.items():
    extent = ax.get_tightbbox(fig.canvas.get_renderer()) \
               .transformed(fig.dpi_scale_trans.inverted())
    fig_bar.savefig(base + f'{name}.pdf', bbox_inches=extent, dpi=300)
print(f'\u2713 Saved: {out_bar}')

# %% [markdown]
# ### Section 8 Notes
#
# Why did we choose 2.52 and 0.27 for the representative metabolizer values?

# %% [markdown]
# ## Simulation Notes

# %% [markdown]
# ### Dose Adjustment Only Optimizer
#
# ### Frequency Adjustment Only Optimizer
#
# ### Joint Optimizer
#
#
# This is the key asymmetry between the two optimizers:
#
#   Column 1: Free variable
#   Dose optimizer: Dose
#   Frequency optimizer: τ
#   ────────────────────────────────────────
#   Column 1: Target metric
#   Dose optimizer: AUC_ss = Dose / CL_ss
#   Frequency optimizer: Cavg_ss = AUC_ss / τ
#   ────────────────────────────────────────
#   Column 1: Why the metric is sensitive to the variable
#   Dose optimizer: Dose appears in the numerator — direct linear relationship
#   Frequency optimizer: Raw AUC_ss is blind to τ; only Cavg_ss carries τ
#     information
#
#   Cavg_ss is the appropriate AUC analog for frequency adjustment precisely
#   because it divides by τ, making it sensitive to interval changes. The current
#   choice is correct. Switching to raw AUC_ss would be like trying to steer a car
#    by adjusting the radio volume — the control has no connection to the outcome.
#
#
#
#
#
# Why is the optimal dose always 10(c_in)?
#
#   At steady state, for a linear PK system:
#
#   AUC_ss = Dose / CL_ss
#
#   In the hybrid model, steady-state clearance scales linearly with c_in:
#
#   CL_ss = c_in × CL_max
#
#   So to match the reference AUC (100 mg, c_in = 1.0):
#
#   D_optimal / (c_in × CL_max) = 100 / (1.0 × CL_max)
#
#   Solving:
#
#   D_optimal = 100 × c_in
#
#   The optimizer is recovering this analytical relationship. For your phenotypes:
#   - Fast (c_in = 2.52) → 252 mg
#   - Slow (c_in = 0.27) → 27 mg
#
#   This is a consequence of the linear structure of the model — clearance is
#   proportional to c_in, so dose must scale proportionally to preserve AUC. If
#   the model included nonlinear elements (saturable absorption, protein binding,
#   etc.) you'd deviate from this clean relationship. It's not an artifact; it's
#   the optimizer correctly identifying the scaling law embedded in the model
#   structure.

# %% [markdown]
# L-BFGS-B stands for Limited-memory Broyden–Fletcher–Goldfarb–Shanno with
#   Bounds. It's a gradient-based optimization algorithm. Breaking down the name:
#
#   ---
#   BFGS is a classic algorithm for finding the minimum of a function. At each
#   step it:
#   1. Estimates the curvature of the objective function (the Hessian matrix — a
#   matrix of second derivatives)
#   2. Uses that curvature estimate to take a well-informed step toward the
#   minimum, rather than just following the steepest descent
#
#   The key insight is that knowing the curvature tells you not just which
#   direction to go, but how far to step — avoiding the overshooting problem of
#   simple gradient descent.
#
#   Limited-memory (L-) means instead of storing and computing the full Hessian
#   matrix (which for $n$ parameters requires $O(n^2)$ memory), it approximates it
#    using only the last $m$ gradient evaluations (typically $m \approx 10$). For
#   your problem with a single parameter (dose or interval), this distinction
#   doesn't matter much, but it makes the algorithm tractable for high-dimensional
#    problems.
#
#   Bounds (-B) means the optimizer respects box constraints — lower and upper
#   bounds on each parameter. This is how bounds=[(10.0, 300.0)] is enforced in
#   your dose optimization; the algorithm will never evaluate the objective
#   outside that range.
#
#   ---
#   Why it's appropriate here:
#
#   Your objective functions are smooth (the PK model is a continuous ODE
#   solution), single-parameter, and bounded — exactly the setting L-BFGS-B is
#   designed for. The algorithm computes numerical gradients of the objective
#   (e.g., how does AUC_ss change as dose changes?) and uses them to converge
#   efficiently.
#
#   The main limitation in your use case is that L-BFGS-B can converge to a local
#   minimum rather than the global one — which is why find_optimal_interval uses
#   four initial guesses. Your objective functions are likely convex (AUC
#   increases monotonically with dose), so in practice this is not a concern for
#   dose optimization, but the interval problem is less obviously convex, hence
#   the multiple restarts.

# %% [markdown]
# As a future direction, would it be possible to try and optimize all three
#    PK metrics in parallel?
#
# ⏺ Yes, this is called multi-objective optimization and it's well-supported in
#   Python. Here's how it would work conceptually and practically:
#
#   ---
#   The core challenge
#
#   Cmax, Cmin, and AUC are not independently controllable with a single dosing
#   parameter (dose or interval). For a rapid metabolizer with high clearance,
#   matching AUC forces a high dose which drives Cmax up and still leaves Cmin low
#    — you can't simultaneously satisfy all three with one degree of freedom.
#   There is an inherent trade-off.
#
#   ---
#   Two main approaches
#
#   1. Weighted sum (scalarization) — collapse the three objectives into one:
#
#   $$\min_D ; w_1 \left(\frac{\text{AUC} -
#   \text{AUC}^{\text{ref}}}{\text{AUC}^{\text{ref}}}\right)^2 + w_2
#   \left(\frac{C_{max} - C_{max}^{\text{ref}}}{C_{max}^{\text{ref}}}\right)^2 +
#   w_3 \left(\frac{C_{min} -
#   C_{min}^{\text{ref}}}{C_{min}^{\text{ref}}}\right)^2$$
#
#   The normalization by the reference value puts all three metrics on the same
#   scale. Weights $w_1, w_2, w_3$ reflect clinical priorities — for Lorlatinib
#   you might weight Cmin most heavily given the 100 ng/mL threshold. This is the
#   simplest extension and could be dropped into find_optimal_dose with minimal
#   changes.
#
#   2. Pareto optimization — treat them as genuinely separate objectives and map
#   out the trade-off surface. Libraries like scipy don't support this natively,
#   but pymoo does. The output is a Pareto front — a set of solutions where you
#   cannot improve one metric without worsening another. This is more informative
#   but also more complex to implement and interpret.
#
#   ---
#   However, there's a fundamental limitation with a single dosing parameter
#
#   With only dose or interval as the free variable, you have one degree of
#   freedom — you can't fully satisfy three constraints simultaneously. The
#   weighted sum approach would find the best compromise, not a perfect match on
#   all three.
#
#   To get closer to matching all three metrics, you would need two free variables
#    simultaneously — for example optimizing dose and interval together. That
#   gives you more flexibility to independently control both the total exposure
#   (AUC) and the peak-to-trough fluctuation (Cmax/Cmin ratio). This would be a
#   natural extension of the current framework and is clinically realistic since
#   both dose and frequency are adjustable in practice.
#
#   ---
#   Would you like me to implement either the weighted sum approach or the joint
#   dose+interval optimization as an additional section in the notebook?

# %% [markdown]
# Would it be possible to modulate dose and frequency together?
#
# ⏺ Yes — and it's actually a cleaner formulation than either single-parameter
#   approach. Here's how it would work:
#
#   ---
#   The optimization problem
#
#   You now have two free variables, optimized simultaneously:
#
#   $$\min_{D,, \tau} ; w_1 \left(\frac{\text{AUC}\tau -
#   \text{AUC}^{\text{ref}}}{\text{AUC}^{\text{ref}}}\right)^2 + w_2
#   \left(\frac{C{max} - C_{max}^{\text{ref}}}{C_{max}^{\text{ref}}}\right)^2 +
#   w_3 \left(\frac{C_{min} -
#   C_{min}^{\text{ref}}}{C_{min}^{\text{ref}}}\right)^2$$
#
#   With the same bounds as before: $D \in [10, 300]$ mg, $\tau \in [6, 48]$ h.
#
#   ---
#   Why this works better
#
#   The three PK metrics encode different aspects of the concentration-time
#   profile:
#
#   - AUC is primarily controlled by $D/CL$ — mostly a function of dose
#   - Cmax is primarily controlled by how much drug arrives quickly — mostly a
#   function of dose relative to volume
#   - Cmin is primarily controlled by how much time elapses between doses — mostly
#    a function of interval
#
#   With only dose as a free variable, Cmax and AUC move together, leaving Cmin as
#    a dependent consequence. With both free, you can adjust interval to control
#   the trough independently of total exposure.
#
#   ---
#   An important practical constraint
#
#   The dosing interval should ideally be a clinically practical value — 12h
#   (BID), 24h (QD), 48h (Q2D) — rather than a continuous output like 17.3h. You
#   could handle this either by:
#   - Rounding the optimal interval to the nearest practical schedule after
#   optimization
#   - Constraining to a discrete set {12, 24, 48} and running three separate
#   optimizations
#
#   ---
#   Expected behavior for each phenotype
#
#   Phenotype: Rapid (c_in=2.52)
#   Expected optimal strategy: Higher dose + shorter interval — raises both AUC
#   and
#     trough
#   ────────────────────────────────────────
#   Phenotype: Poor (c_in=0.27)
#   Expected optimal strategy: Lower dose + longer interval — reduces AUC and
#     prevents excessive accumulation
#
#   ---
#   Would you like me to implement this as a new section in the notebook?

# %% [markdown]
# ### Why does dose only adjustment perfectly match AUC to target but frequency only adjustment does not?
#
# **This comes down to a fundamental difference in how dose and frequency interact with clearance in a linear PK system.**
#
#   **Why dose adjustment matches AUC exactly**
#
# At steady state:
#
# AUC = Dose / CL_ss = Dose / (c_in × CL)
#
# At steady-stateWhen you scale dose by c_in (e.g., 252 mg for the fast metabolizer), the c_in
# terms cancel exactly:
#
# AUC_adj = (c_in × Dose_adj) / (c_in × CL_base) = Dose_ref / CL_base = AUC_ref
#
# This is a mathematical identity — it holds for every metric simultaneously
# because in a linear system all concentrations scale proportionally with dose.
# Cmax and Cmin are matched for the same reason.
#
#   Why frequency adjustment cannot match AUC
#
#   Changing the dosing interval does not change how much drug enters the body per
#    dose or how fast it is cleared. With a fixed 100 mg dose:
#
#   AUC per dosing interval = 100 / (c_in × CL_base)
#
#   This is independent of τ — it is fixed by dose and clearance alone. For the
#   fast metabolizer, this is always 1/2.52 of the reference AUC regardless of how
#    often you dose. There is no interval you can choose that recovers the lost
#   exposure per dose.
#
#   What interval can change is Cavg (= AUC/τ, average concentration). By
#   shortening τ you deliver more doses per unit time, so Cavg increases. The τ
#   that would match Cavg is 24/2.52 ≈ 9.5h. However, the optimizer is
#   simultaneously trying to minimize errors in Cmax, Cmin, and AUC/Cavg — three
#   constraints with only one free parameter. These three metrics respond
#   differently to interval changes (Cmin is particularly sensitive to τ because
#   it depends on how much drug remains before the next dose), so the optimizer
#   settles on a compromise τ that reduces total error but cannot perfectly
#   satisfy all three at once.
#
#   In short: dose adjustment has an exact algebraic cancellation mechanism (Dose
#   × 1/c_in kills the c_in in the denominator), while frequency adjustment has no
#    equivalent — it can redistribute exposure across time but cannot recover the
#   per-dose exposure deficit caused by higher clearance.

# %% [markdown]
# Great, thank you! Finally, is AUC over the final interval clinically
#   meaningful or do clinicians consider total AUC?
#
# ⏺ Both are used, but they serve different purposes:
#
#   AUC over the final (steady-state) interval is generally what is most
#   clinically relevant for chronic dosing like Lorlatinib. It represents the drug
#    exposure a patient experiences during one typical dosing cycle at steady
#   state — this is what gets compared to efficacy and toxicity thresholds in
#   PK/PD studies. It is often reported as AUC_ss or AUC_τ (AUC over one dosing
#   interval τ).
#
#   Total AUC (from time 0 to infinity) is more relevant for single-dose studies —
#    for example, bioavailability calculations or characterizing a drug after a
#   one-time administration.
#
#   For a drug like Lorlatinib taken daily long-term, the steady-state interval
#   AUC is the more meaningful quantity because:
#
#   1. Patients spend the vast majority of their treatment time at steady state,
#   not during the initial accumulation phase
#   2. It is the repeating exposure that drives both efficacy (tumor suppression)
#   and toxicity
#   3. It is directly comparable across regimens with different dosing intervals
#   when expressed as Cavg = AUC_τ / τ — which is exactly why the frequency
#   optimizer in your model uses Cavg rather than raw AUC

# %% [markdown]
# ## 9. Joint Dose + Frequency Optimization
#
# Optimize dose and dosing interval simultaneously, minimizing a weighted sum of squared relative errors across all three steady-state PK metrics ($C_{max}$, $C_{min}$, AUC). With two free variables, the optimizer can independently control total exposure (via dose) and peak-to-trough fluctuation (via interval).

# %%
def find_optimal_dose_and_interval(c_in_target, target_metrics,
                                   weights=(1.0, 1.0, 1.0),
                                   cmin_lower_bound=None):
    """
    Find optimal dose AND dosing interval simultaneously for a given c_in.

    Minimizes weighted sum of squared relative errors for Cmax, Cmin, and AUC.
    A 3x3 grid of initial guesses is used to reduce sensitivity to local minima.

    Parameters
    ----------
    c_in_target : float
    target_metrics : dict
    weights : tuple (w_auc, w_cmax, w_cmin)
    cmin_lower_bound : float or None
        If set, enforces Cmin >= cmin_lower_bound (ng/mL) via a quadratic
        penalty term. Violations are penalised as 1e3 * ((lb - Cmin)/lb)^2,
        which dominates the objective whenever Cmin falls below the threshold.

    Returns
    -------
    (optimal_dose, optimal_interval) : (float, float)
    """
    # Both dose and interval vary during optimisation; use 100 mg / 24 h as the
    # reference for find_steady_state (same reasoning as find_optimal_interval).
    n_doses = find_steady_state(c_in_target, dose_mg=100.0, dosing_interval=24.0)

    w_auc, w_cmax, w_cmin = weights

    def objective(params):
        dose, interval = params[0], params[1]

        model = HybridModel(c_in=c_in_target)
        sim = model.simulate_multiple_doses(
            dose_mg=dose, n_doses=n_doses, dosing_interval=interval
        )
        metrics = calculate_final_metrics(sim, dosing_interval=interval)

        err_auc  = w_auc  * ((metrics['AUC_f']  - target_metrics['AUC_f'])
                              / target_metrics['AUC_f'])**2
        err_cmax = w_cmax * ((metrics['Cmax_f'] - target_metrics['Cmax_f'])
                              / target_metrics['Cmax_f'])**2
        err_cmin = w_cmin * ((metrics['Cmin_f'] - target_metrics['Cmin_f'])
                              / target_metrics['Cmin_f'])**2

        # Quadratic penalty if Cmin falls below the lower bound
        penalty = 0.0
        if cmin_lower_bound is not None and metrics['Cmin_f'] < cmin_lower_bound:
            penalty = 1e3 * ((cmin_lower_bound - metrics['Cmin_f'])
                             / cmin_lower_bound) ** 2

        return err_auc + err_cmax + err_cmin + penalty

    # Scale dose grid and upper bound with c_in (optimal dose ∝ c_in in linear PK)
    dose_upper = max(600.0, 200.0 * c_in_target)

    # 3x3 grid of initial guesses for robustness against local minima
    best_result = None
    best_error  = np.inf

    for dose_init in [50.0 * c_in_target, 100.0 * c_in_target, 200.0 * c_in_target]:
        for interval_init in [12.0, 24.0, 36.0]:
            result = minimize(
                objective,
                x0=[dose_init, interval_init],
                bounds=[(10.0, dose_upper), (6.0, 48.0)],
                method='L-BFGS-B'
            )
            if result.fun < best_error:
                best_error  = result.fun
                best_result = result

    return best_result.x[0], best_result.x[1]

print('\u2713 find_optimal_dose_and_interval defined')

# %% [markdown]
# ## 10. Run Joint Optimization
#
# Run for both phenotypes and compare against single-parameter strategies.

# %%
print("Running joint dose + frequency optimization...")
print("(9 initial guesses per phenotype \u2014 may take a moment)\n")

# ── Rapid metabolizer ─────────────────────────────────────────────────────────
dose_fast_joint, interval_fast_joint = find_optimal_dose_and_interval(
    c_in_fast, metrics_ref, weights=(1.0, 1.0, 1.0),
    cmin_lower_bound=150.0
)
model_fast_joint = HybridModel(c_in=c_in_fast)
n_doses_fj = int(max(480, interval_fast_joint * 20) / interval_fast_joint)
sim_fast_joint = model_fast_joint.simulate_multiple_doses(
    dose_mg=dose_fast_joint, n_doses=n_doses_fj, dosing_interval=interval_fast_joint
)
metrics_fast_joint = calculate_final_metrics(
    sim_fast_joint, dosing_interval=interval_fast_joint
)

print(f"Rapid metabolizer (c_in = {c_in_fast}):")
print(f"  Joint regimen:    {dose_fast_joint:.1f} mg every {interval_fast_joint:.1f} h")
print(f"  Dose-only:        {dose_fast:.1f} mg Q24h")
print()
print(f"  {'Metric':<10} {'Reference':>12} {'Dose-only':>12} {'Joint':>12}")
print(f"  {'-'*48}")
for m, label in [('Cmax_f','Cmax (ng/mL)'), ('Cmin_f','Cmin (ng/mL)'), ('AUC_f','AUC (ng\u00b7h/mL)')]:
    print(f"  {label:<14} {metrics_ref[m]:>10.1f} {metrics_fast_dose[m]:>12.1f} {metrics_fast_joint[m]:>12.1f}")

print()

# ── Poor metabolizer ──────────────────────────────────────────────────────────
dose_slow_joint, interval_slow_joint = find_optimal_dose_and_interval(
    c_in_slow, metrics_ref, weights=(1.0, 1.0, 1.0),
    cmin_lower_bound=150.0
)
model_slow_joint = HybridModel(c_in=c_in_slow)
n_doses_sj = int(max(480, interval_slow_joint * 20) / interval_slow_joint)
sim_slow_joint = model_slow_joint.simulate_multiple_doses(
    dose_mg=dose_slow_joint, n_doses=n_doses_sj, dosing_interval=interval_slow_joint
)
metrics_slow_joint = calculate_final_metrics(
    sim_slow_joint, dosing_interval=interval_slow_joint
)

print(f"Poor metabolizer (c_in = {c_in_slow}):")
print(f"  Joint regimen:    {dose_slow_joint:.1f} mg every {interval_slow_joint:.1f} h")
print(f"  Dose-only:        {dose_slow:.1f} mg Q24h")
print()
print(f"  {'Metric':<10} {'Reference':>12} {'Dose-only':>12} {'Joint':>12}")
print(f"  {'-'*48}")
for m, label in [('Cmax_f','Cmax (ng/mL)'), ('Cmin_f','Cmin (ng/mL)'), ('AUC_f','AUC (ng\u00b7h/mL)')]:
    print(f"  {label:<14} {metrics_ref[m]:>10.1f} {metrics_slow_dose[m]:>12.1f} {metrics_slow_joint[m]:>12.1f}")

# %% [markdown]
# ## 11. Visualization: Joint Optimization

# %%
plt.rcParams['axes.titlepad'] = 12
base = (
    '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
    'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
)

# ── Panel A: Fast metabolizer — joint optimization ────────────────────────
fig_a, ax = plt.subplots(figsize=(10, 5))
ax.plot(sim_ref['time']/24, sim_ref['C_central'],
        'darkorange', lw=4, label='c$_{in}$=1, 100mg QD')
ax.plot(t_fast_unadj_days, sim_fast_unadj['C_central'], '-', color='darkred', linewidth=2, alpha=0.9,
         label='c$_{in}$=2.52, 100mg QD')
ax.plot(sim_fast_joint['time']/24, sim_fast_joint['C_central'],
        color='blue', linewidth=2, alpha=0.7,
        label=f'c$_{{in}}$=2.52, {dose_fast_joint:.0f} mg Q{interval_fast_joint:.1f}h')
ax.set_xlim(16, 18)
ax.set_ylim(0, 800)
ax.set_xticks([16,17,18],[16,17,18])
ax.set_xlabel('Time (days)', fontsize=18)
ax.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_a.savefig(base + 'Fig3A.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S13_PanelA.pdf')

# ── Panel B: Slow metabolizer — joint optimization ────────────────────────
fig_b, ax = plt.subplots(figsize=(10, 5))
ax.plot(sim_ref['time']/24, sim_ref['C_central'],
        'darkorange', lw=4, label='c$_{in}$=1, 100mg QD')
ax.plot(t_slow_unadj_days, sim_slow_unadj['C_central'], color='gold', linewidth=2, alpha=0.9,
         label='c$_{in}$=0.27, 100mg QD')
ax.plot(sim_slow_joint['time']/24, sim_slow_joint['C_central'],
        'g-', lw=2, label=f'c$_{{in}}$=0.27, {dose_slow_joint:.0f} mg Q{interval_slow_joint:.1f}h')
ax.set_xlim(13, 18)
ax.set_ylim(0, 1200)
ax.set_xlabel('Time (days)', fontsize=18)
ax.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_b.savefig(base + 'Fig3C.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S13_PanelB.pdf')

# ── Panel C: Bar chart — joint optimization PK metrics ────────────────────
fig_c, ax = plt.subplots(figsize=(10, 5))
metrics_names = ['AUC_f', 'Cmax_f', 'Cmin_f']
ref_vals   = [metrics_ref[m]        for m in metrics_names]
fast_norm  = [(metrics_fast_joint[m]/r)*100 for m, r in zip(metrics_names, ref_vals)]
slow_norm  = [(metrics_slow_joint[m]/r)*100 for m, r in zip(metrics_names, ref_vals)]
ref_norm   = [100] * 3

x, w = np.arange(3), 0.25
ax.bar(x - w, ref_norm,  w, label='c$_{in}$=1, 100mg QD', color='darkorange')
ax.bar(x,     fast_norm, w, label=f'c$_{{in}}$=2.52, {dose_fast_joint:.0f} mg Q{interval_fast_joint:.1f}h', color='blue', alpha=0.7)
ax.bar(x + w, slow_norm, w, label=f'c$_{{in}}$=0.27, {dose_slow_joint:.0f} mg Q{interval_slow_joint:.1f}h', color='g')

ax.axhline(100, color='black', linestyle='-',  linewidth=1.5)
ax.axhline(90,  color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax.axhline(110, color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% Target Value')

all_norm = ref_norm + fast_norm + slow_norm
ax.set_ylim(min(all_norm) * 0.90, max(all_norm) * 1.10)
ax.set_ylabel('% of SOC', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(['AUC', 'C$_{max}$', 'C$_{min}$'], fontsize=18)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
#fig_c.savefig(base + 'Fig3.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: Fig3C.pdf')

print(f'Slow = {dose_slow_joint:.0f} mg Q{interval_slow_joint:.0f}h')
print(f'Fast = {dose_fast_joint:.0f} mg Q{interval_fast_joint:.0f}h')

# %%
# =========================================================================
# Section 13: Bar Graph — Joint Optimization Comparison
# =========================================================================
# Cavg_f (= AUC_f / tau) is used for AUC to allow fair comparison
# across regimens with different dosing intervals.

metrics_fast_unadj = calculate_final_metrics(sim_fast_unadj)
metrics_slow_unadj = calculate_final_metrics(sim_slow_unadj)

plt.rcParams['axes.titlepad'] = 12
base = (
    '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
    'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
)

metric_keys = ['Cavg_f', 'Cmax_f', 'Cmin_f']
x_labels    = ['AUC', 'C$_{max}$', 'C$_{min}$']
x           = np.arange(3)
w           = 0.25

# ── Fast metabolizer ───────────────────────────────────────────────────────
fig_f, ax_f = plt.subplots(figsize=(9, 7))
ref_vals_f   = [metrics_ref[k]        for k in metric_keys]
unadj_vals_f = [metrics_fast_unadj[k] for k in metric_keys]
joint_vals_f = [metrics_fast_joint[k] for k in metric_keys]

ref_norm_f   = [100] * 3
unadj_norm_f = [(v/r)*100 for v, r in zip(unadj_vals_f, ref_vals_f)]
joint_norm_f = [(v/r)*100 for v, r in zip(joint_vals_f, ref_vals_f)]

ax_f.bar(x - w, ref_norm_f,   w, label=f'c$_{{in}}$=1.0, 100 mg QD', color='darkorange')
ax_f.bar(x,     unadj_norm_f, w, label=f'c$_{{in}}$={c_in_fast}, 100 mg QD', color='darkred', alpha=0.9)
ax_f.bar(x + w, joint_norm_f, w, label=f'c$_{{in}}$={c_in_fast}, {dose_fast_joint:.0f} mg Q{interval_fast_joint:.0f}h', color='blue', alpha=0.7)

ax_f.axhline(100, color='black', ls='-',  lw=1.5)
ax_f.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')
ax_f.set_xticks(x)
ax_f.set_xticklabels(x_labels, fontsize=18)
ax_f.set_ylabel('% SOC', fontsize=18)
ax_f.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
all_f = ref_norm_f + unadj_norm_f + joint_norm_f
ax_f.set_ylim(min(all_f) * 0.90, max(all_f) * 1.15)
ax_f.spines['top'].set_visible(False)
ax_f.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_f.savefig(base + 'Fig3B.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: Fig3B.pdf')

# ── Slow metabolizer ───────────────────────────────────────────────────────
fig_s, ax_s = plt.subplots(figsize=(9, 7))
ref_vals_s   = [metrics_ref[k]        for k in metric_keys]
unadj_vals_s = [metrics_slow_unadj[k] for k in metric_keys]
joint_vals_s = [metrics_slow_joint[k] for k in metric_keys]

ref_norm_s   = [100] * 3
unadj_norm_s = [(v/r)*100 for v, r in zip(unadj_vals_s, ref_vals_s)]
joint_norm_s = [(v/r)*100 for v, r in zip(joint_vals_s, ref_vals_s)]

ax_s.bar(x - w, ref_norm_s,   w, label=f'c$_{{in}}$=1.0, 100 mg QD', color='darkorange')
ax_s.bar(x,     unadj_norm_s, w, label=f'c$_{{in}}$={c_in_slow}, 100 mg QD', color='gold', alpha=0.9)
ax_s.bar(x + w, joint_norm_s, w, label=f'c$_{{in}}$={c_in_slow}, {dose_slow_joint:.0f} mg Q{interval_slow_joint:.0f}h', color='g')

ax_s.axhline(100, color='black', ls='-',  lw=1.5)
ax_s.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')
ax_s.set_xticks(x)
ax_s.set_xticklabels(x_labels, fontsize=18)
ax_s.set_ylabel('% SOC', fontsize=18)
ax_s.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
all_s = ref_norm_s + unadj_norm_s + joint_norm_s
ax_s.set_ylim(min(all_s) * 0.90, max(all_s) * 1.15)
ax_s.spines['top'].set_visible(False)
ax_s.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_s.savefig(base + 'Fig3D.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: Fig3D.pdf')

# %% [markdown]
# ## 14. Discrete Grid Joint Optimization
#
# Repeat the joint dose + frequency optimization, but restrict the search to a clinically practical grid:
#
# - **Doses:** 25, 50, 75, … 300 mg (25 mg steps)
# - **Intervals:** 12, 24, 36, 48, 60, 72 h (12 h steps)
#
# All 72 combinations are evaluated by brute-force; the one minimising the same weighted sum of squared relative errors (AUC, Cmax, Cmin) is selected.

# %%
dose_grid     = [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300]  # mg
interval_grid = [12, 24, 36, 48, 60, 72] # hours

def find_optimal_on_grid(c_in_target, target_metrics, dose_grid, interval_grid,
                         weights=(1.0, 1.0, 1.0)):
    """
    Brute-force grid search over all (dose, interval) combinations.
    Returns the combination with the lowest weighted sum of squared relative errors
    across Cmax, Cmin, and AUC.
    """
    w_auc, w_cmax, w_cmin = weights
    best_error    = np.inf
    best_dose     = None
    best_interval = None

    for dose in dose_grid:
        for interval in interval_grid:
            model   = HybridModel(c_in=c_in_target)
            n_doses = int(max(480, interval * 20) / interval)
            sim     = model.simulate_multiple_doses(
                dose_mg=dose, n_doses=n_doses, dosing_interval=interval
            )
            m = calculate_final_metrics(sim, dosing_interval=interval)

            err = (w_auc  * ((m['AUC_f']  - target_metrics['AUC_f'])  / target_metrics['AUC_f'])**2
                 + w_cmax * ((m['Cmax_f'] - target_metrics['Cmax_f']) / target_metrics['Cmax_f'])**2
                 + w_cmin * ((m['Cmin_f'] - target_metrics['Cmin_f']) / target_metrics['Cmin_f'])**2)

            if err < best_error:
                best_error    = err
                best_dose     = dose
                best_interval = interval

    return best_dose, best_interval

print(f"Grid: {len(dose_grid)} doses \u00d7 {len(interval_grid)} intervals = "
      f"{len(dose_grid)*len(interval_grid)} combinations per phenotype")
print("Running grid search...\n")

#Rapid metabolizer 
dose_fast_grid, interval_fast_grid = find_optimal_on_grid(
    c_in_fast, metrics_ref, dose_grid, interval_grid
)
model_fast_grid = HybridModel(c_in=c_in_fast)
n_doses_fg = int(max(480, interval_fast_grid * 20) / interval_fast_grid)
sim_fast_grid = model_fast_grid.simulate_multiple_doses(
    dose_mg=dose_fast_grid, n_doses=n_doses_fg, dosing_interval=interval_fast_grid
)
metrics_fast_grid = calculate_final_metrics(sim_fast_grid, dosing_interval=interval_fast_grid)

print(f"Rapid metabolizer (c_in = {c_in_fast}):")
print(f"  Grid-optimal:   {dose_fast_grid} mg Q{interval_fast_grid}h")
print(f"  Continuous:     {dose_fast_joint:.1f} mg Q{interval_fast_joint:.1f}h")
print(f"  {'Metric':<14} {'Reference':>12} {'Grid':>12} {'Continuous':>12}")
print(f"  {'-'*52}")
for m, label in [('Cmax_f','Cmax (ng/mL)'), ('Cmin_f','Cmin (ng/mL)'), ('AUC_f','AUC (ng\u00b7h/mL)')]:
    print(f"  {label:<14} {metrics_ref[m]:>12.1f} {metrics_fast_grid[m]:>12.1f} {metrics_fast_joint[m]:>12.1f}")

print()

# Poor metabolizer 
dose_slow_grid, interval_slow_grid = find_optimal_on_grid(
    c_in_slow, metrics_ref, dose_grid, interval_grid
)
model_slow_grid = HybridModel(c_in=c_in_slow)
n_doses_sg = int(max(480, interval_slow_grid * 20) / interval_slow_grid)
sim_slow_grid = model_slow_grid.simulate_multiple_doses(
    dose_mg=dose_slow_grid, n_doses=n_doses_sg, dosing_interval=interval_slow_grid
)
metrics_slow_grid = calculate_final_metrics(sim_slow_grid, dosing_interval=interval_slow_grid)

print(f"Poor metabolizer (c_in = {c_in_slow}):")
print(f"  Grid-optimal:   {dose_slow_grid} mg Q{interval_slow_grid}h")
print(f"  Continuous:     {dose_slow_joint:.1f} mg Q{interval_slow_joint:.1f}h")
print(f"  {'Metric':<14} {'Reference':>12} {'Grid':>12} {'Continuous':>12}")
print(f"  {'-'*52}")
for m, label in [('Cmax_f','Cmax (ng/mL)'), ('Cmin_f','Cmin (ng/mL)'), ('AUC_f','AUC (ng\u00b7h/mL)')]:
    print(f"  {label:<14} {metrics_ref[m]:>12.1f} {metrics_slow_grid[m]:>12.1f} {metrics_slow_joint[m]:>12.1f}")

# %%
plt.rcParams['axes.titlepad'] = 12
base = (
    '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
    'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
)

# ── Panel A: Fast metabolizer ──────────────────────────────────────────────
fig_a, ax = plt.subplots(figsize=(10, 7))
ax.plot(sim_ref['time']/24, sim_ref['C_central'],
        'darkorange', lw=4, label='c$_{in}$ = 1, 100mg QD')
ax.plot(t_fast_unadj_days, sim_fast_unadj['C_central'], color='darkred', linewidth=2, alpha=0.9,
         label='c$_{in}$=2.52, 100mg QD')
ax.plot(sim_fast_grid['time']/24, sim_fast_grid['C_central'],
        color='blue', alpha=0.7, lw=2, label=f'c$_{{in}}$ = 2.52, {dose_fast_grid:.0f}mg Q{interval_fast_grid:.0f}h')
ax.set_xlim(16, 18)
ax.set_xticks([16,17,18],[16,17,18])
ax.set_ylim(0, 800)
ax.set_xlabel('Time (days)', fontsize=18)
ax.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_a.savefig(base + 'Fig3_SuppFigA.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S14_PanelA.pdf')

# ── Panel B: Slow metabolizer ──────────────────────────────────────────────
fig_b, ax = plt.subplots(figsize=(10, 7))
ax.plot(sim_ref['time']/24, sim_ref['C_central'],
        'darkorange', lw=4, label='c$_{in}$ = 1, 100mg QD')
ax.plot(t_slow_unadj_days, sim_slow_unadj['C_central'], color='gold', linewidth=2, alpha=0.9,
         label='c$_{in}$=0.27, 100mg QD')
ax.plot(sim_slow_grid['time']/24, sim_slow_grid['C_central'],
        'g-', lw=2, label=f'c$_{{in}}$=0.27, {dose_slow_grid:.0f}mg Q{interval_slow_grid:.0f}h')
ax.set_xlim(12, 18)
ax.set_ylim(0, 1200)
ax.set_xlabel('Time (days)', fontsize=18)
ax.set_ylabel('lorlatinib (ng/mL)', fontsize=18)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_b.savefig(base + 'Fig3_Supp3C.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S14_PanelB.pdf')

# ── Panel C: Bar chart ─────────────────────────────────────────────────────
fig_c, ax = plt.subplots(figsize=(8, 7))
metrics_names = ['AUC_f', 'Cmax_f', 'Cmin_f']
ref_vals  = [metrics_ref[m]        for m in metrics_names]
fast_norm = [(metrics_fast_grid[m]/r)*100 for m, r in zip(metrics_names, ref_vals)]
slow_norm = [(metrics_slow_grid[m]/r)*100 for m, r in zip(metrics_names, ref_vals)]
ref_norm  = [100] * 3

x, w = np.arange(3), 0.25
ax.bar(x - w, ref_norm,  w, label='c$_{in}$ = 1, 100mg QD', color='b', alpha=0.7)
ax.bar(x,     fast_norm, w, label='Fast Metabolizer', color='#ED7D31', alpha=0.8)
ax.bar(x + w, slow_norm, w, label='Slow Metabolizer', color='g', alpha=0.7)

ax.axhline(100, color='black', linestyle='-',  linewidth=1.5)
ax.axhline(90,  color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax.axhline(110, color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% Av Metabolizer')

all_norm = ref_norm + fast_norm + slow_norm
ax.set_ylim(min(all_norm) * 0.90, max(all_norm) * 1.20)
ax.set_ylabel('% of SOC', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(['AUC', 'Cmax', 'Cmin'], fontsize=18)
ax.legend(loc='upper left', fontsize=18)
ax.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()
#fig_c.savefig(base + 'S14_PanelC.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S14_PanelC.pdf')

print(f"Fast = ({dose_fast_grid} mg Q{interval_fast_grid}h)")
print(f"Slow = ({dose_slow_grid} mg Q{interval_slow_grid}h)")

# %%
# =========================================================================
# Section 14: Bar Graph — Discrete Grid Optimization Comparison
# =========================================================================
# Cavg_ss (= AUC_ss / tau) is used for AUC to allow fair comparison
# across regimens with different dosing intervals.

plt.rcParams['axes.titlepad'] = 12
base = (
    '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
    'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
)

metric_keys = ['Cavg_f', 'Cmax_f', 'Cmin_f']
x_labels    = ['AUC', 'C$_{max}$', 'C$_{min}$']
x           = np.arange(3)
w           = 0.25

# ── Fast metabolizer ───────────────────────────────────────────────────────
fig_f, ax_f = plt.subplots(figsize=(9, 7))
ref_vals_f   = [metrics_ref[k]        for k in metric_keys]
unadj_vals_f = [metrics_fast_unadj[k] for k in metric_keys]
grid_vals_f  = [metrics_fast_grid[k]  for k in metric_keys]

ref_norm_f   = [100] * 3
unadj_norm_f = [(v/r)*100 for v, r in zip(unadj_vals_f, ref_vals_f)]
grid_norm_f  = [(v/r)*100 for v, r in zip(grid_vals_f,  ref_vals_f)]

ax_f.bar(x - w, ref_norm_f,   w, label=f'c$_{{in}}$=1.0, 100 mg QD', color='darkorange')
ax_f.bar(x,     unadj_norm_f, w, label=f'c$_{{in}}$={c_in_fast}, 100 mg QD', color='darkred', alpha=0.9)
ax_f.bar(x + w, grid_norm_f,  w, label=f'c$_{{in}}$={c_in_fast}, {dose_fast_grid} mg Q{interval_fast_grid}h', color='blue', alpha=0.7)

ax_f.axhline(100, color='black', ls='-',  lw=1.5)
ax_f.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_f.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')
ax_f.set_xticks(x)
ax_f.set_xticklabels(x_labels, fontsize=18)
ax_f.set_ylabel('% SOC', fontsize=18)
ax_f.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
all_f = ref_norm_f + unadj_norm_f + grid_norm_f
ax_f.set_ylim(min(all_f) * 0.90, max(all_f) * 1.15)
ax_f.spines['top'].set_visible(False)
ax_f.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_f.savefig(base + 'Fig3_Supp3B.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S3_Bar1.pdf')

# ── Slow metabolizer ───────────────────────────────────────────────────────
fig_s, ax_s = plt.subplots(figsize=(9, 7))
ref_vals_s   = [metrics_ref[k]        for k in metric_keys]
unadj_vals_s = [metrics_slow_unadj[k] for k in metric_keys]
grid_vals_s  = [metrics_slow_grid[k]  for k in metric_keys]

ref_norm_s   = [100] * 3
unadj_norm_s = [(v/r)*100 for v, r in zip(unadj_vals_s, ref_vals_s)]
grid_norm_s  = [(v/r)*100 for v, r in zip(grid_vals_s,  ref_vals_s)]

ax_s.bar(x - w, ref_norm_s,   w, label=f'c$_{{in}}$=1.0, 100 mg QD', color='darkorange')
ax_s.bar(x,     unadj_norm_s, w, label=f'c$_{{in}}$={c_in_slow}, 100 mg QD', color='gold', alpha=0.9)
ax_s.bar(x + w, grid_norm_s,  w, label=f'c$_{{in}}$={c_in_slow}, {dose_slow_grid} mg Q{interval_slow_grid}h', color='g')

ax_s.axhline(100, color='black', ls='-',  lw=1.5)
ax_s.axhline(90,  color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhline(110, color='gray',  ls='--', lw=1, alpha=0.5)
ax_s.axhspan(90, 110, alpha=0.15, color='green', label='\u00b110% target')
ax_s.set_xticks(x)
ax_s.set_xticklabels(x_labels, fontsize=18)
ax_s.set_ylabel('% SOC', fontsize=18)
ax_s.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)
all_s = ref_norm_s + unadj_norm_s + grid_norm_s
ax_s.set_ylim(min(all_s) * 0.90, max(all_s) * 1.15)
ax_s.spines['top'].set_visible(False)
ax_s.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()
fig_s.savefig(base + 'Fig3_Supp3D.pdf', dpi=300, bbox_inches='tight')
print('\u2713 Saved: S3_Bar2.pdf')

# %% [markdown]
# ## 14. Visualization: Before vs After Single Param Adjustment

# %%
# Unadjusted simulations: each phenotype at standard 100 mg QD
print("Simulating unadjusted phenotypes at standard 100 mg QD...")

model_fast_std = HybridModel(c_in=c_in_fast)
sim_fast_std   = model_fast_std.simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
metrics_fast_std = calculate_final_metrics(sim_fast_std, dosing_interval=24)

model_slow_std = HybridModel(c_in=c_in_slow)
sim_slow_std   = model_slow_std.simulate_multiple_doses(dose_mg=100, n_doses=18, dosing_interval=24)
metrics_slow_std = calculate_final_metrics(sim_slow_std, dosing_interval=24)

print(f"Fast unadjusted (c_in={c_in_fast}, 100 mg QD):")
print(f"  Cmax={metrics_fast_std['Cmax_f']:.1f}  Cmin={metrics_fast_std['Cmin_f']:.1f}  AUC={metrics_fast_std['AUC_f']:.1f} ng\u00b7h/mL")
print(f"Slow unadjusted (c_in={c_in_slow}, 100 mg QD):")
print(f"  Cmax={metrics_slow_std['Cmax_f']:.1f}  Cmin={metrics_slow_std['Cmin_f']:.1f}  AUC={metrics_slow_std['AUC_f']:.1f} ng\u00b7h/mL")
print("\u2713 Unadjusted simulations complete")

# %%
from matplotlib.gridspec import GridSpecFromSubplotSpec
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

# Colour scheme: light = unadjusted, dark = adjusted
C_FAST_LIGHT = '#F5B97F'   # light orange
C_FAST_DARK  = '#C85A00'   # dark orange
C_SLOW_LIGHT = '#9DD18A'   # light green
C_SLOW_DARK  = '#2E7D32'   # dark green

fig_ba = plt.figure(figsize=(18, 9))
gs_ba  = fig_ba.add_gridspec(2, 3, hspace=0.55, wspace=0.32)

def pk_panel_ba(ax, t_std, C_std, col_std,
                    t_adj, C_adj, col_adj,
                    t_ref, C_ref, title):
    """Plot reference, unadjusted, and adjusted curves. No per-panel legend."""
    ax.plot(t_ref/24, C_ref, 'b-',  lw=1.8, alpha=0.55)
    ax.plot(t_std/24, C_std, '--', lw=2.2, color=col_std, alpha=0.85)
    ax.plot(t_adj/24, C_adj, '-',  lw=2.5, color=col_adj)
    ax.set_xlim(12, 18)
    ax.set_xlabel('Time (days)', fontsize=18, fontweight='bold')
    ax.set_ylabel('Plasma Concentration (ng/mL)', fontsize=18, fontweight='bold')
    ax.set_title(title, fontsize=18, fontweight='bold')
    ax.grid(True, alpha=0.3)

# ── Row 1: Dose Adjustment ------------------------------------------------
pk_panel_ba(fig_ba.add_subplot(gs_ba[0, 0]),
    sim_fast_std['time'],  sim_fast_std['C_central'],  C_FAST_LIGHT,
    sim_fast_dose['time'], sim_fast_dose['C_central'], C_FAST_DARK,
    sim_ref['time'], sim_ref['C_central'],
    f'A. Fast Metabolizer: Dose Adjustment\n 100 mg QD \u2192 {dose_fast:.0f} mg QD')

pk_panel_ba(fig_ba.add_subplot(gs_ba[0, 1]),
    sim_slow_std['time'],  sim_slow_std['C_central'],  C_SLOW_LIGHT,
    sim_slow_dose['time'], sim_slow_dose['C_central'], C_SLOW_DARK,
    sim_ref['time'], sim_ref['C_central'],
    f'B. Slow Metabolizer: Dose Adjustment\n 100 mg QD \u2192 {dose_slow:.0f} mg QD')

# Panel C: broken y-axis bar chart ----------------------------------------
mnames = ['AUC_f', 'Cmax_f', 'Cmin_f']
rv  = [metrics_ref[m] for m in mnames]
fu  = [(metrics_fast_std[m]/r)*100  for m, r in zip(mnames, rv)]
fa  = [(metrics_fast_dose[m]/r)*100 for m, r in zip(mnames, rv)]
su  = [(metrics_slow_std[m]/r)*100  for m, r in zip(mnames, rv)]
sa  = [(metrics_slow_dose[m]/r)*100 for m, r in zip(mnames, rv)]
x, w = np.arange(3), 0.18

gs_c = GridSpecFromSubplotSpec(2, 1, subplot_spec=gs_ba[0, 2],
                               hspace=0.0, height_ratios=[1, 2.5])
ax_c_top = fig_ba.add_subplot(gs_c[0])
ax_c_bot = fig_ba.add_subplot(gs_c[1])

bk = dict(edgecolor='grey', linewidth=0.5)
for ax in [ax_c_top, ax_c_bot]:
    ax.bar(x - 1.5*w, fu, w, color=C_FAST_LIGHT, label=f'Fast unadj. (100 mg)',   **bk)
    ax.bar(x - 0.5*w, fa, w, color=C_FAST_DARK,  label=f'Fast adj. ({dose_fast:.0f} mg)',    **bk)
    ax.bar(x + 0.5*w, su, w, color=C_SLOW_LIGHT, label=f'Slow unadj. (100 mg)',   **bk)
    ax.bar(x + 1.5*w, sa, w, color=C_SLOW_DARK,  label=f'Slow adj. ({dose_slow:.0f} mg)',     **bk)
    ax.set_xticks(x)
    ax.grid(True, alpha=0.3, axis='y')

ax_c_top.set_ylim(325, 675)
ax_c_bot.set_ylim(-5,  225)

ax_c_bot.axhline(100, color='black', linewidth=1.5, label='Reference target (100%)')
ax_c_bot.axhline(90,  color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax_c_bot.axhline(110, color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax_c_bot.fill_between([-0.5, 2.5], 90, 110, alpha=0.1, color='green')

for xi, val in [(x[0] + 0.5*w, su[0]), (x[2] + 0.5*w, su[2])]:
    ax_c_top.text(xi, val + 10, f'{val:.0f}%', ha='center', va='bottom',
                 fontsize=18, fontweight='bold', color=C_SLOW_DARK)

ax_c_top.spines['bottom'].set_visible(False)
ax_c_bot.spines['top'].set_visible(False)
ax_c_top.tick_params(bottom=False, labelbottom=False)

# ── Axis break marks on left/right borders ────────────────────────────────
d   = 0.013   # tick half-length in axes fraction
sep = 0.018   # separation between the two parallel lines
kw_brk = dict(clip_on=False, lw=1.2, color='#333333', zorder=11)

for _ax, _y0 in [(ax_c_top, 0), (ax_c_bot, 1)]:
    for _x0 in [0, 1]:  # left and right border
        _ax.plot([_x0 - d, _x0 + d], [_y0 - d - sep, _y0 + d - sep],
                 transform=_ax.transAxes, **kw_brk)
        _ax.plot([_x0 - d, _x0 + d], [_y0 - d + sep, _y0 + d + sep],
                 transform=_ax.transAxes, **kw_brk)

# ── Break marks on the truncated bars (su AUC and su Cmin) ─────────────────
dy_bar = 7        # half-height of break mark in data units
dx_sep = w * 0.3  # x-offset between the two parallel diagonal lines

for xi in [x[0] + 0.5*w, x[2] + 0.5*w]:
    for _ax, y_brk in [(ax_c_bot, 225), (ax_c_top, 325)]:
        # White cover to cleanly cut the bar colour
        _ax.add_patch(mpatches.Rectangle(
            (xi - w/2 - 0.01, y_brk - dy_bar),
            w + dx_sep + 0.02, 2 * dy_bar,
            facecolor='white', edgecolor='none', zorder=8, clip_on=False
        ))
        # Line 1
        _ax.plot([xi - w/2,           xi + w/2          ],
                 [y_brk - dy_bar,     y_brk + dy_bar    ],
                 '-', color='#333333', lw=1.2, zorder=9, clip_on=False)
        # Line 2 (parallel, shifted right)
        _ax.plot([xi - w/2 + dx_sep,  xi + w/2 + dx_sep ],
                 [y_brk - dy_bar,     y_brk + dy_bar    ],
                 '-', color='#333333', lw=1.2, zorder=9, clip_on=False)

ax_c_bot.set_xticklabels(['AUC', 'Cmax', 'Cmin'], fontsize=18)
ax_c_bot.set_ylabel('% of Reference', fontsize=18, fontweight='bold')
ax_c_top.legend(loc='upper left', fontsize=18)
ax_c_top.set_title('C. Dose Adjustment: PK Match', fontsize=18, fontweight='bold')

# ── Row 2: Frequency Adjustment -------------------------------------------
pk_panel_ba(fig_ba.add_subplot(gs_ba[1, 0]),
    sim_fast_std['time'],  sim_fast_std['C_central'],  C_FAST_LIGHT,
    sim_fast_freq['time'], sim_fast_freq['C_central'], C_FAST_DARK,
    sim_ref['time'], sim_ref['C_central'],
    f'D. Fast Metabolizer: Frequency Adjustment\n Q24h \u2192 Q{interval_fast:.0f}h')

pk_panel_ba(fig_ba.add_subplot(gs_ba[1, 1]),
    sim_slow_std['time'],  sim_slow_std['C_central'],  C_SLOW_LIGHT,
    sim_slow_freq['time'], sim_slow_freq['C_central'], C_SLOW_DARK,
    sim_ref['time'], sim_ref['C_central'],
    f'E. Slow Metabolizer: Frequency Adjustment\n Q24h \u2192 Q{interval_slow:.0f}h')

# Panel F: broken y-axis bar chart (mirrors Panel C) ─────────────────────
mnames_f = ['AUC_f', 'Cmax_f', 'Cmin_f']
rv_f   = [metrics_ref[m] for m in mnames_f]
fu_f   = [(metrics_fast_std[m]/r)*100  for m, r in zip(mnames_f, rv_f)]
fa_f   = [(metrics_fast_freq[m]/r)*100 for m, r in zip(mnames_f, rv_f)]
su_f   = [(metrics_slow_std[m]/r)*100  for m, r in zip(mnames_f, rv_f)]
sa_f   = [(metrics_slow_freq[m]/r)*100 for m, r in zip(mnames_f, rv_f)]
x_f, w_f = np.arange(3), 0.18

gs_f     = GridSpecFromSubplotSpec(2, 1, subplot_spec=gs_ba[1, 2],
                                   hspace=0.0, height_ratios=[1, 2.5])
ax_f_top = fig_ba.add_subplot(gs_f[0])
ax_f_bot = fig_ba.add_subplot(gs_f[1])

bk_f = dict(edgecolor='grey', linewidth=0.5)
for ax in [ax_f_top, ax_f_bot]:
    ax.bar(x_f - 1.5*w_f, fu_f, w_f, color=C_FAST_LIGHT, label=f'Fast unadj. (100 mg)',        **bk_f)
    ax.bar(x_f - 0.5*w_f, fa_f, w_f, color=C_FAST_DARK,  label=f'Fast adj. (Q{interval_fast:.0f}h)', **bk_f)
    ax.bar(x_f + 0.5*w_f, su_f, w_f, color=C_SLOW_LIGHT, label=f'Slow unadj. (100 mg)',        **bk_f)
    ax.bar(x_f + 1.5*w_f, sa_f, w_f, color=C_SLOW_DARK,  label=f'Slow adj. (Q{interval_slow:.0f}h)',  **bk_f)
    ax.set_xticks(x_f)
    ax.grid(True, alpha=0.3, axis='y')

ax_f_top.set_ylim(325, 675)
ax_f_bot.set_ylim(-5,  225)

ax_f_bot.axhline(100, color='black', linewidth=1.5, label='Reference target (100%)')
ax_f_bot.axhline(90,  color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax_f_bot.axhline(110, color='gray',  linestyle='--', linewidth=1, alpha=0.5)
ax_f_bot.fill_between([-0.5, 2.5], 90, 110, alpha=0.1, color='green')

for xi, val in [(x_f[0] + 0.5*w_f, su_f[0]), (x_f[2] + 0.5*w_f, su_f[2])]:
    ax_f_top.text(xi, val + 10, f'{val:.0f}%', ha='center', va='bottom',
                  fontsize=18, fontweight='bold', color=C_SLOW_DARK)

ax_f_top.spines['bottom'].set_visible(False)
ax_f_bot.spines['top'].set_visible(False)
ax_f_top.tick_params(bottom=False, labelbottom=False)

# ── Axis break marks on left/right borders ────────────────────────────────
for _ax, _y0 in [(ax_f_top, 0), (ax_f_bot, 1)]:
    for _x0 in [0, 1]:
        _ax.plot([_x0 - d, _x0 + d], [_y0 - d - sep, _y0 + d - sep],
                 transform=_ax.transAxes, **kw_brk)
        _ax.plot([_x0 - d, _x0 + d], [_y0 - d + sep, _y0 + d + sep],
                 transform=_ax.transAxes, **kw_brk)

# ── Break marks on the truncated bars (su AUC and su Cmin) ────────────────
dx_sep_f = w_f * 0.3
for xi in [x_f[0] + 0.5*w_f, x_f[2] + 0.5*w_f]:
    for _ax, y_brk in [(ax_f_bot, 225), (ax_f_top, 325)]:
        _ax.add_patch(mpatches.Rectangle(
            (xi - w_f/2 - 0.01, y_brk - dy_bar),
            w_f + dx_sep_f + 0.02, 2 * dy_bar,
            facecolor='white', edgecolor='none', zorder=8, clip_on=False
        ))
        _ax.plot([xi - w_f/2,             xi + w_f/2            ],
                 [y_brk - dy_bar,          y_brk + dy_bar        ],
                 '-', color='#333333', lw=1.2, zorder=9, clip_on=False)
        _ax.plot([xi - w_f/2 + dx_sep_f,  xi + w_f/2 + dx_sep_f],
                 [y_brk - dy_bar,          y_brk + dy_bar        ],
                 '-', color='#333333', lw=1.2, zorder=9, clip_on=False)

ax_f_bot.set_xticklabels(['AUC', 'Cmax', 'Cmin'], fontsize=18)
ax_f_bot.set_ylabel('% of Reference', fontsize=18, fontweight='bold')
ax_f_top.legend(loc='upper left', fontsize=18)
ax_f_top.set_title('F. Frequency Adjustment: PK Match', fontsize=18, fontweight='bold')

# ── Shared figure-level legend for PK panels (A, B, D, E) ----------------
legend_elements = [
    Line2D([0],[0], color='b',          lw=1.8, alpha=0.55,          label='Reference (c_in=1.0, 100 mg QD)'),
    Line2D([0],[0], color=C_FAST_LIGHT, lw=2.2, ls='--', alpha=0.85, label=f'Fast metabolizer unadjusted (c_in={c_in_fast})'),
    Line2D([0],[0], color=C_FAST_DARK,  lw=2.5,                       label=f'Fast metabolizer adjusted (c_in={c_in_fast})'),
    Line2D([0],[0], color=C_SLOW_LIGHT, lw=2.2, ls='--', alpha=0.85, label=f'Slow metabolizer unadjusted (c_in={c_in_slow})'),
    Line2D([0],[0], color=C_SLOW_DARK,  lw=2.5,                       label=f'Slow metabolizer adjusted (c_in={c_in_slow})'),
]
fig_ba.legend(handles=legend_elements, loc='lower center',
              bbox_to_anchor=(0.33, -0.04), ncol=3,
              fontsize=18, framealpha=0.9, frameon=True,
              bbox_transform=fig_ba.transFigure)

fig_ba.suptitle('Personalized Lorlatinib Dosing: Before vs. After Regimen Adjustment',
                fontsize=18, fontweight='bold', y=1.01)
plt.tight_layout(rect=[0, 0.07, 1, 1])
plt.show()
print('\u2713 Before-vs-After figure generated')

# %%
output_path_ba = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2025/'
                  'Lorlatinib_Human_PKProject_30Jan2026/Hybrid_Model/Figures/'
                  'PersonalizedRegimens_BeforeAfter.png')
#fig_ba.savefig(output_path_ba, dpi=300, bbox_inches='tight')
print(f'\u2713 Saved: {output_path_ba}')

# %% [markdown]
# ## 15. AUC vs c_in Curve
#
# Sweep c_in from 0.05 to 10 at standard 100 mg QD to visualize how steady-state AUC varies continuously across the full range of CYP3A4 metabolizer phenotypes.

# %%
#Whole Range 
#Sweep c_in from 0.05 to 10 at standard 100 mg QD
print("Computing steady-state PK metrics across c_in range 0.05 → 10...")
c_in_sweep = np.concatenate([np.linspace(0.05, 1.0, 30), np.linspace(1.0, 10.0, 40)[1:]])

auc_sweep, cmax_sweep, cmin_sweep = [], [], []
for i, c in enumerate(c_in_sweep):
    sim = HybridModel(c_in=c).simulate_multiple_doses(100, 18, 24)
    m   = calculate_final_metrics(sim, dosing_interval=24)
    auc_sweep.append(m['AUC_f'])
    cmax_sweep.append(m['Cmax_f'])
    cmin_sweep.append(m['Cmin_f'])
    if (i+1) % 20 == 0:
        print(f"  {i+1}/{len(c_in_sweep)}  c_in={c:.2f}  AUC={m['AUC_f']:.0f}")

c_in_sweep = np.array(c_in_sweep)
auc_sweep  = np.array(auc_sweep)
cmax_sweep = np.array(cmax_sweep)
cmin_sweep = np.array(cmin_sweep)
print(f"\u2713 Sweep complete ({len(c_in_sweep)} points)")

ref_idx    = np.argmin(np.abs(c_in_sweep - 1.0))
auc_ref_v  = auc_sweep[ref_idx]
cmax_ref_v = cmax_sweep[ref_idx]
cmin_ref_v = cmin_sweep[ref_idx]

COL_AUC  = '#212121'
COL_CMAX = '#C62828'
COL_CMIN = '#7B2D8B'
PHENO = [(0.27, 'Slow',    'green'),
         (1.00, 'Average', 'blue'),
         (2.52, 'Fast',   '#ED7D31')]

from matplotlib.lines import Line2D

fig_cin, ax = plt.subplots(figsize=(13, 8))

l1, = ax.plot(c_in_sweep, auc_sweep/auc_ref_v*100,   '-', color=COL_AUC,  lw=2.5, zorder=3)
l2, = ax.plot(c_in_sweep, cmax_sweep/cmax_ref_v*100, '-', color=COL_CMAX, lw=2.0, zorder=3)
l3, = ax.plot(c_in_sweep, cmin_sweep/cmin_ref_v*100, '-', color=COL_CMIN, lw=2.0, zorder=3)

for c_val, name, col in PHENO:
    idx = np.argmin(np.abs(c_in_sweep - c_val))
    ax.axvline(c_in_sweep[idx], color=col, ls=':', lw=1.5, alpha=1, zorder=2)
    ax.scatter(c_in_sweep[idx], auc_sweep[idx]/auc_ref_v*100,   color=col, s=75, zorder=5)
    ax.scatter(c_in_sweep[idx], cmax_sweep[idx]/cmax_ref_v*100, color=col, s=65, zorder=5, marker='^'
)
    ax.scatter(c_in_sweep[idx], cmin_sweep[idx]/cmin_ref_v*100, color=col, s=65, zorder=5, marker='s')
    ax.text(c_val * 1.1, 0.96, f'{name}\nc$_{{in}}$={c_val}',
             ha='left', va='top', fontsize=15, color=col,
             transform=ax.get_xaxis_transform())

ax.set_yscale('log')
ax.set_xscale('linear')
ax.set_xlim(0.05, 10)
ax.set_xlabel('c$_{in}$ Value', fontsize=18)
ax.set_ylabel('% SOC', fontsize=18)
ax.grid(True, alpha=0.22, which='major', zorder=0)
ax.legend(handles=[l1, l2, l3],
           labels=['AUC (% SOC)', 'C$_{max}$ (% SOC)', 'C$_{min}$ (% SOC)'],
           fontsize=18, loc='upper right', framealpha=0.9)

plt.tight_layout()
plt.show()

out_cin = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
           'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
           'Fig1B.pdf')
#fig_cin.savefig(out_cin, dpi=300, bbox_inches='tight')
print(f'\u2713 Saved: {out_cin}')

# %%
# Zoomed view: dense c_in sampling range (0.05 – 1.0)
mask = c_in_sweep <= 1.0
c_in_zoom   = c_in_sweep[mask]
auc_zoom    = auc_sweep[mask]
cmax_zoom   = cmax_sweep[mask]
cmin_zoom   = cmin_sweep[mask]

COL_AUC  = '#212121'
COL_CMAX = '#C62828'
COL_CMIN = '#7B2D8B'
PHENO = [(0.27, 'Slow',    'green'),
         (1.00, 'Average', 'blue')]

from matplotlib.lines import Line2D

fig_zoom, ax = plt.subplots(figsize=(13, 8))

l1z, = ax.plot(c_in_zoom, auc_zoom/auc_ref_v*100,   '-', color=COL_AUC,  lw=2.5, zorder=3)
l2z, = ax.plot(c_in_zoom, cmax_zoom/cmax_ref_v*100, '-', color=COL_CMAX, lw=2.0, zorder=3)
l3z, = ax.plot(c_in_zoom, cmin_zoom/cmin_ref_v*100, '-', color=COL_CMIN, lw=2.0, zorder=3)

for c_val, name, col in PHENO:
    if c_val > 1.0:
        continue
    idx = np.argmin(np.abs(c_in_zoom - c_val))
    ax.axvline(c_in_zoom[idx], color=col, ls=':', lw=1.5, alpha=0.65, zorder=2)
    ax.scatter(c_in_zoom[idx], auc_zoom[idx]/auc_ref_v*100,   color=col, s=75, zorder=5)
    ax.scatter(c_in_zoom[idx], cmax_zoom[idx]/cmax_ref_v*100, color=col, s=65, zorder=5, marker='^'
)
    ax.scatter(c_in_zoom[idx], cmin_zoom[idx]/cmin_ref_v*100, color=col, s=65, zorder=5, marker='s')
    ax.text(c_val*1.05, 0.96, f'{name}\nc$_{{in}}$={c_val}',
              ha='left', va='top', fontsize=18, color=col, fontweight='bold',
              transform=ax.get_xaxis_transform())

ax.set_yscale('log')
ax.set_xscale('linear')
ax.set_xlim(0.05, 1.0)
ax.set_xlabel('c$_{in}$ Value', fontsize=18)
ax.set_ylabel('% SOC', fontsize=18)
ax.grid(True, alpha=0.22, which='major', zorder=0)
ax.legend(handles=[l1z, l2z, l3z],
            labels=['AUC (% SOC)', 'C$_{max}$ (% SOC)', 'C$_{min}$ (% SOC)'],
            fontsize=18, loc='upper right', framealpha=0.9)

plt.tight_layout()
plt.show()

out_zoom = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
            'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
            'Fig1_Supp1A.pdf')
#fig_zoom.savefig(out_zoom, dpi=300, bbox_inches='tight')
print(f'\u2713 Saved: {out_zoom}')

# %%
# AUC vs c_in: range c_in >= 1.0
mask = c_in_sweep >= 1.0
c_in_zoom   = c_in_sweep[mask]
auc_zoom    = auc_sweep[mask]
cmax_zoom   = cmax_sweep[mask]
cmin_zoom   = cmin_sweep[mask]

COL_AUC  = '#212121'
COL_CMAX = '#C62828'
COL_CMIN = '#7B2D8B'
PHENO = [(0.27, 'Slow',    'green'),
         (1.00, 'Average', 'blue'),
         (2.52, 'Fast',    '#ED7D31')]

from matplotlib.lines import Line2D

fig_zoom, ax = plt.subplots(figsize=(13, 8))

l1z, = ax.plot(c_in_zoom, auc_zoom/auc_ref_v*100,   '-', color=COL_AUC,  lw=2.5, zorder=3)
l2z, = ax.plot(c_in_zoom, cmax_zoom/cmax_ref_v*100, '-', color=COL_CMAX, lw=2.0, zorder=3)
l3z, = ax.plot(c_in_zoom, cmin_zoom/cmin_ref_v*100, '-', color=COL_CMIN, lw=2.0, zorder=3)

for c_val, name, col in PHENO:
    if c_val < 1.0:
        continue
    idx = np.argmin(np.abs(c_in_zoom - c_val))
    ax.axvline(c_in_zoom[idx], color=col, ls=':', lw=1.5, alpha=0.65, zorder=2)
    ax.scatter(c_in_zoom[idx], auc_zoom[idx]/auc_ref_v*100,   color=col, s=75, zorder=5)
    ax.scatter(c_in_zoom[idx], cmax_zoom[idx]/cmax_ref_v*100, color=col, s=65, zorder=5, marker='^'
)
    ax.scatter(c_in_zoom[idx], cmin_zoom[idx]/cmin_ref_v*100, color=col, s=65, zorder=5, marker='s')
    y_pos = 0.86 if name == 'Fast' else 0.75
    ax.text(c_val*1.09, y_pos, f'{name}\nc$_{{in}}$={c_val}',
              ha='left', va='top', fontsize=18, color=col, fontweight='bold',
              transform=ax.get_xaxis_transform())

ax.set_yscale('log')
ax.set_xscale('linear')
ax.set_xlim(1.0, 10.0)
ax.set_xlabel('c$_{in}$', fontsize=18)
ax.set_ylabel('% SOC', fontsize=18)
ax.grid(True, alpha=0.22, which='major', zorder=0)
ax.legend(handles=[l1z, l2z, l3z],
            labels=['AUC (% SOC)', 'C$_{max}$ (% SOC)', 'C$_{min}$ (% SOC)'],
            fontsize=18, loc='lower left', framealpha=0.9)

plt.tight_layout()
plt.show()

out_zoom = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
            'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
            'Fig1_Supp1B.pdf')
#fig_zoom.savefig(out_zoom, dpi=300, bbox_inches='tight')
print(f'\u2713 Saved: {out_zoom}')

# %% [markdown]
# ## 16. Solution Set Visualization
#
# Plot AUC vs Cmax across a dose range of 10–300 mg QD for each metabolizer phenotype.
# Each curve traces the achievable (AUC, Cmax) space as dose increases.
# The optimal dose (minimizing deviation from the reference) is marked with a star.

# %%
# =========================================================================
# Section 16a: Impact of Dose Adjustment on AUC, Cmax, and Cmin
# =========================================================================
#print("Sweeping doses 0–1250 mg for AUC/Cmax/Cmin impact visualization...")

dose_sweep_v2 = np.linspace(0, 1250, 60)

PHENO_SOL2 = [
    (c_in_slow, 'Slow', 'green', dose_slow),
    (1.00, 'Average', 'blue', 100.0),
    (5, 'c$_{in}$ = 5','#ED7D31', dose_fast),
]

# Collect metrics for each phenotype across dose range
results = {}
for c_in_val, label, col, opt_dose in PHENO_SOL2:
    aucs, cmaxs, cmins = [], [], []
    for d in dose_sweep_v2:
        sim = HybridModel(c_in=c_in_val).simulate_multiple_doses(d, 18, 24)
        m   = calculate_final_metrics(sim, dosing_interval=24)
        aucs.append(m['AUC_f'])
        cmaxs.append(m['Cmax_f'])
        cmins.append(m['Cmin_f'])
    results[label] = dict(col=col, opt_dose=opt_dose,
                          aucs=np.array(aucs),
                          cmaxs=np.array(cmaxs),
                          cmins=np.array(cmins))
    print(f'  ✓ {label}')

# SOC reference values (average metabolizer)
ref_auc  = metrics_ref['AUC_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

fig_dose, axes_dose = plt.subplots(1, 3, figsize=(22, 8))
plt.rcParams['axes.titlepad'] = 12

metrics_plot = [
    ('aucs',  ref_auc,  'AUC (% of SOC)',       (10, 300)),
    ('cmaxs', ref_cmax, 'C$_{max}$ (% of SOC)', (10, 300)),
    ('cmins', ref_cmin, 'C$_{min}$ (% of SOC)', (10, 300)),
]

for ax, (key, ref_val, ylabel, xlims) in zip(axes_dose, metrics_plot):
    for label, data in results.items():
        pct = data[key] / ref_val * 100
        ax.plot(dose_sweep_v2, pct, '-', color=data['col'],
                lw=2.0, alpha=0.85, label=label)
        opt_idx = np.argmin(np.abs(dose_sweep_v2 - data['opt_dose']))
        ax.scatter(dose_sweep_v2[opt_idx], pct[opt_idx],
                   color=data['col'], s=150, zorder=6, marker='*',
                   edgecolors='black', linewidths=0.6)

    ax.axhline(100, color='black', ls='--', lw=1.5, alpha=0.7, label='SOC (100%)')
    ax.set_xlabel('Dose (mg)', fontsize=18)
    ax.set_ylabel(ylabel, fontsize=18)
    ax.set_xlim(*xlims)
    ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)

plt.tight_layout()
plt.show()

out_dose = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
            'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
            'Fig4A.pdf')
#fig_dose.savefig(out_dose, dpi=300, bbox_inches='tight')
print(f'✓ Saved: {out_dose}')

# %%
# =========================================================================
# Section 16d: Impact of Frequency Adjustment on AUC/tau, Cmax, and Cmin
# =========================================================================
#print("Sweeping intervals 4–48 h for frequency impact visualization...")

interval_sweep2 = np.geomspace(1, 96, 120)  # log-spaced: denser at short intervals where fast-metabolizer curves are steep

PHENO_FREQ = [
    (c_in_slow, 'Slow', 'green', interval_slow),
    (1.00, 'Average', 'blue', 24.0),
    (5, 'c$_{in}$ = 5', '#ED7D31', interval_fast),
]

results_freq = {}
for c_in_val, label, col, opt_interval in PHENO_FREQ:
    cavgs, cmaxs, cmins = [], [], []
    for tau in interval_sweep2:
        n = max(20, int(500 / tau))
        sim = HybridModel(c_in=c_in_val).simulate_multiple_doses(100, n, tau)
        m   = calculate_final_metrics(sim, dosing_interval=tau)
        cavgs.append(m['Cavg_f'])
        cmaxs.append(m['Cmax_f'])
        cmins.append(m['Cmin_f'])
    from scipy.ndimage import gaussian_filter1d
    results_freq[label] = dict(col=col, opt_interval=opt_interval,
                               cavgs=gaussian_filter1d(np.array(cavgs), sigma=2),
                               cmaxs=gaussian_filter1d(np.array(cmaxs), sigma=2),
                               cmins=gaussian_filter1d(np.array(cmins), sigma=2))
    print(f'  ✓ {label}')

# SOC reference values (average metabolizer)
ref_cavg = metrics_ref['Cavg_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

fig_fq_imp, axes_fq = plt.subplots(1, 3, figsize=(22, 8))
plt.rcParams['axes.titlepad'] = 12

metrics_fq = [
    ('cavgs', ref_cavg, 'AUC/$\\tau$ (% of SOC)'),
    ('cmaxs', ref_cmax, 'C$_{max}$ (% of SOC)'),
    ('cmins', ref_cmin, 'C$_{min}$ (% of SOC)'),
]

for ax, (key, ref_val, ylabel) in zip(axes_fq, metrics_fq):
    for label, data in results_freq.items():
        pct = data[key] / ref_val * 100
        ax.plot(interval_sweep2, pct, '-', color=data['col'],
                lw=2.0, alpha=0.85, label=label)
        opt_idx = np.argmin(np.abs(interval_sweep2 - data['opt_interval']))
        ax.scatter(interval_sweep2[opt_idx], pct[opt_idx],
                   color=data['col'], s=150, zorder=6, marker='*',
                   edgecolors='black', linewidths=0.6)

    ax.axhline(100, color='black', ls='--', lw=1.5, alpha=0.7, label='SOC (100%)')
    ax.set_xlabel('Dosing Interval (h)', fontsize=18)
    ax.set_ylabel(ylabel, fontsize=18)
    ax.set_xlim(0, 96)
    ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize=18, frameon=False)

plt.tight_layout()
plt.show()

out_fq_imp = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
              'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
              'Fig4B.pdf')
#fig_fq_imp.savefig(out_fq_imp, dpi=300, bbox_inches='tight')
print(f'✓ Saved: {out_fq_imp}')

# %%
# =========================================================================
# Section 16: AUC/Cmax/Cmin vs Dose — % of SOC, single y-axis
# =========================================================================
# Reuses: dose_sweep_v2, results (computed in Section 16a)

from matplotlib.lines import Line2D

COL_AUC  = '#212121'
COL_CMAX = '#C62828'
COL_CMIN = '#7B2D8B'

# SOC reference values (average metabolizer)
ref_auc  = metrics_ref['AUC_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

fig_d15, ax_d = plt.subplots(figsize=(13, 8))

for label, data in results.items():
    col = data['col']
    ax_d.plot(dose_sweep_v2, data['aucs']  / ref_auc  * 100, '-',  color=col, lw=2.0, alpha=0.85)
    ax_d.plot(dose_sweep_v2, data['cmaxs'] / ref_cmax * 100, '--', color=col, lw=1.8, alpha=0.85)
    ax_d.plot(dose_sweep_v2, data['cmins'] / ref_cmin * 100, ':',  color=col, lw=1.8, alpha=0.85)
    opt_idx = np.argmin(np.abs(dose_sweep_v2 - data['opt_dose']))
    ax_d.scatter(dose_sweep_v2[opt_idx], data['aucs'][opt_idx]  / ref_auc  * 100,
                 color=col, s=150, zorder=6, marker='*', edgecolors='black', linewidths=0.6)
    ax_d.scatter(dose_sweep_v2[opt_idx], data['cmaxs'][opt_idx] / ref_cmax * 100,
                 color=col, s=80,  zorder=6, marker='^', edgecolors='black', linewidths=0.5)
    ax_d.scatter(dose_sweep_v2[opt_idx], data['cmins'][opt_idx] / ref_cmin * 100,
                 color=col, s=80,  zorder=6, marker='s', edgecolors='black', linewidths=0.5)

ax_d.axhline(100, color='black', ls='--', lw=1.5, alpha=0.6)
ax_d.set_xlim(10, 300)
ax_d.set_xlabel('Dose (mg)', fontsize=18)
ax_d.set_ylabel('% of SOC', fontsize=18)
ax_d.grid(True, alpha=0.22, which='major', zorder=0)

style_handles = [
    Line2D([0],[0], color='gray', lw=2.0, ls='-',  label='AUC'),
    Line2D([0],[0], color='gray', lw=1.8, ls='--', label='C$_{max}$'),
    Line2D([0],[0], color='gray', lw=1.8, ls=':',  label='C$_{min}$'),
    Line2D([0],[0], color='black', lw=1.5, ls='--', label='SOC (100%)'),
]
pheno_handles = [
    Line2D([0],[0], color=data['col'], lw=2.0, label=label)
    for label, data in results.items()
]
ax_d.legend(handles=style_handles + pheno_handles,
            fontsize=18, loc='upper left', framealpha=0.9)

plt.tight_layout()
plt.show()

out_d15 = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
           'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
           'Fig_S16_DoseSweep.pdf')
#fig_d15.savefig(out_d15, dpi=300, bbox_inches='tight')
print(f'✓ Saved: {out_d15}')

# %%
# =========================================================================
# Section 16: Cavg/Cmax/Cmin vs Dosing Interval — % of SOC, single y-axis
# =========================================================================
# Reuses: interval_sweep2, results_freq (computed in Section 16d)

# SOC reference values (average metabolizer)
ref_cavg = metrics_ref['Cavg_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

fig_f15, ax_f = plt.subplots(figsize=(13, 8))

for label, data in results_freq.items():
    col = data['col']
    ax_f.plot(interval_sweep2, data['cavgs'] / ref_cavg * 100, '-',  color=col, lw=2.0, alpha=0.85)
    ax_f.plot(interval_sweep2, data['cmaxs'] / ref_cmax * 100, '--', color=col, lw=1.8, alpha=0.85)
    ax_f.plot(interval_sweep2, data['cmins'] / ref_cmin * 100, ':',  color=col, lw=1.8, alpha=0.85)
    opt_idx = np.argmin(np.abs(interval_sweep2 - data['opt_interval']))
    ax_f.scatter(interval_sweep2[opt_idx], data['cavgs'][opt_idx] / ref_cavg * 100,
                 color=col, s=150, zorder=6, marker='*', edgecolors='black', linewidths=0.6)
    ax_f.scatter(interval_sweep2[opt_idx], data['cmaxs'][opt_idx] / ref_cmax * 100,
                 color=col, s=80,  zorder=6, marker='^', edgecolors='black', linewidths=0.5)
    ax_f.scatter(interval_sweep2[opt_idx], data['cmins'][opt_idx] / ref_cmin * 100,
                 color=col, s=80,  zorder=6, marker='s', edgecolors='black', linewidths=0.5)

ax_f.axhline(100, color='black', ls='--', lw=1.5, alpha=0.6)
ax_f.set_xlim(1, 72)
ax_f.set_xlabel('Dosing Interval (h)', fontsize=18)
ax_f.set_ylabel('% of SOC', fontsize=18)
ax_f.grid(True, alpha=0.22, which='major', zorder=0)

style_handles_f = [
    Line2D([0],[0], color='gray', lw=2.0, ls='-',  label='AUC/$\\tau$'),
    Line2D([0],[0], color='gray', lw=1.8, ls='--', label='C$_{max}$'),
    Line2D([0],[0], color='gray', lw=1.8, ls=':',  label='C$_{min}$'),
    Line2D([0],[0], color='black', lw=1.5, ls='--', label='SOC (100%)'),
]
pheno_handles_f = [
    Line2D([0],[0], color=data['col'], lw=2.0, label=label)
    for label, data in results_freq.items()
]
ax_f.legend(handles=style_handles_f + pheno_handles_f,
            fontsize=18, loc='upper right', framealpha=0.9)

plt.tight_layout()
plt.show()

out_f15 = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
           'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
           'Fig_S16_FreqSweep.pdf')
#fig_f15.savefig(out_f15, dpi=300, bbox_inches='tight')
print(f'✓ Saved: {out_f15}')

# %%
# =========================================================================
# Section 16: Per-metabolizer dose sweep — 1x3 subplots
# =========================================================================
fig_d_sub, axes_d_sub = plt.subplots(1, 3, figsize=(22, 8))

# SOC reference values (average metabolizer)
ref_auc  = metrics_ref['AUC_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

xlims_by_label = {
    'Slow':    (0, 80),
    'Average': (10, 300),
    'c$_{in}$ = 10':    (0, 500),
}

# ── Y-axis limits: set to None for auto-scaling ──────────────────────────────
ylims_dose = {
    'Slow':          (0, 250),   # % SOC axis
    'Average_left':  (0, 15000),   # AUC (ng·h/mL), left axis
    'Average_right': (0, 1500),   # C_max, C_min (ng/mL), right axis
    'c$_{in}$ = 10':          (0, 300),   # % SOC axis
}

for ax, (label, data) in zip(axes_d_sub, results.items()):
    if label == 'Average':
        # Dual y-axis with absolute values
        ax2 = ax.twinx()
        ax.plot( dose_sweep_v2, data['aucs'],  '-', color=COL_AUC,  lw=2.0, alpha=0.9)
        ax2.plot(dose_sweep_v2, data['cmaxs'], '-', color=COL_CMAX, lw=1.8, alpha=0.9)
        ax2.plot(dose_sweep_v2, data['cmins'], '-', color=COL_CMIN, lw=1.8, alpha=0.9)

        for arr, tgt, ax_t, col_m in [
            (data['aucs'],  ref_auc,  ax,  COL_AUC),
            (data['cmaxs'], ref_cmax, ax2, COL_CMAX),
            (data['cmins'], ref_cmin, ax2, COL_CMIN),
        ]:
            if arr.min() <= tgt <= arr.max():
                idx = np.argmin(np.abs(arr - tgt))
                ax_t.scatter(dose_sweep_v2[idx], arr[idx],
                             color=col_m, s=200, zorder=7, marker='*',
                             edgecolors='black', linewidths=0.6)

        ax.set_yscale('linear')
        ax2.set_yscale('linear')
        ax.set_ylabel('AUC (ng·h/mL)', fontsize=18, color=COL_AUC)
        ax2.set_ylabel('C$_{max}$, C$_{min}$ (ng/mL)', fontsize=18, color='#212121')
        ax.tick_params(axis='y', labelcolor=COL_AUC)
        handles_d = [
            Line2D([0],[0], color=COL_AUC,  lw=2.0, ls='-', label='AUC'),
            Line2D([0],[0], color=COL_CMAX, lw=1.8, ls='-', label='C$_{max}$'),
            Line2D([0],[0], color=COL_CMIN, lw=1.8, ls='-', label='C$_{min}$'),
            Line2D([0],[0], color='gray', marker='*', markersize=10, ls='none',
                   markeredgecolor='black', label='SOC Metrics'),
        ]
    else:
        # Single y-axis with % of SOC
        auc_pct  = data['aucs']  / ref_auc  * 100
        cmax_pct = data['cmaxs'] / ref_cmax * 100
        cmin_pct = data['cmins'] / ref_cmin * 100

        ax.plot(dose_sweep_v2, auc_pct,  '-', color=COL_AUC,  lw=2.0, alpha=0.9)
        ax.plot(dose_sweep_v2, cmax_pct, '-', color=COL_CMAX, lw=1.8, alpha=0.9)
        ax.plot(dose_sweep_v2, cmin_pct, '-', color=COL_CMIN, lw=1.8, alpha=0.9)


        ax.axhline(100, color='black', ls='--', lw=1.2, alpha=0.5)
        ax.set_ylabel('% of SOC', fontsize=18)
        handles_d = [
            Line2D([0],[0], color=COL_AUC,  lw=2.0, ls='-', label='AUC'),
            Line2D([0],[0], color=COL_CMAX, lw=1.8, ls='-', label='C$_{max}$'),
            Line2D([0],[0], color=COL_CMIN, lw=1.8, ls='-', label='C$_{min}$'),
        ]

    ax.set_title(f'{label}', fontsize=18, fontweight='bold')
    ax.set_xlabel('Dose (mg)', fontsize=18)
    ax.set_xlim(*xlims_by_label[label])
    if label == 'Average':
        ax.set_ylim(*ylims_dose['Average_left'])
        ax2.set_ylim(*ylims_dose['Average_right'])
    else:
        ax.set_ylim(*ylims_dose[label])
    ax.legend(handles=handles_d, fontsize=12, loc='upper right', framealpha=0.9)

plt.tight_layout()
out_d_sub = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
             'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
             'Fig2A.pdf')
#fig_d_sub.savefig(out_d_sub, dpi=300, bbox_inches='tight')
plt.show()

# %%
# =========================================================================
# Section 16: Per-metabolizer dose sweep — individual subplot figures
# Save each subplot at exactly the size it appears in the combined figure
# =========================================================================
fig_d_sub.canvas.draw()
renderer_d = fig_d_sub.canvas.get_renderer()

for ax, label in zip(axes_d_sub, results.keys()):
    out_d_ind = '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/' + f'Fig2A_{label}.pdf'
    extent = ax.get_tightbbox(renderer_d).transformed(
        fig_d_sub.dpi_scale_trans.inverted()
    )
    fig_d_sub.savefig(out_d_ind, bbox_inches=extent, dpi=300)
    print(f'\u2713 Saved: {out_d_ind}')

# %%
# =========================================================================
# Section 16: Per-metabolizer frequency sweep — 1x3 subplots
# =========================================================================
fig_f_sub, axes_f_sub = plt.subplots(1, 3, figsize=(22, 8))

# SOC reference values (average metabolizer)
ref_cavg = metrics_ref['Cavg_f']
ref_cmax = metrics_ref['Cmax_f']
ref_cmin = metrics_ref['Cmin_f']

xlims_by_label_freq = {
    'Slow':    (72, 96),
    'Average': (1, 48),
    'c$_{in}$ = 5': (1, 24),
}

# ── Y-axis limits: set to None for auto-scaling ──────────────────────────────
ylims_freq = {
    'Slow':          (75, 175),   # % SOC axis
    'Average_left':  (0, 1000),   # AUC/τ (ng/mL), left axis
    'Average_right': (0, 1000),   # C_max, C_min (ng/mL), right axis
    'c$_{in}$ = 5':    (0, 200),   # % SOC axis
}

for ax, (label, data) in zip(axes_f_sub, results_freq.items()):
    if label == 'Average':
        # Dual y-axis with absolute values
        ax2 = ax.twinx()
        ax.plot( interval_sweep2, data['cavgs'], '-', color=COL_AUC,  lw=2.0, alpha=0.9)
        ax2.plot(interval_sweep2, data['cmaxs'], '-', color=COL_CMAX, lw=1.8, alpha=0.9)
        ax2.plot(interval_sweep2, data['cmins'], '-', color=COL_CMIN, lw=1.8, alpha=0.9)

        for arr, tgt, ax_t, col_m in [
            (data['cavgs'], ref_cavg, ax,  COL_AUC),
            (data['cmaxs'], ref_cmax, ax2, COL_CMAX),
            (data['cmins'], ref_cmin, ax2, COL_CMIN),
        ]:
            if arr.min() <= tgt <= arr.max():
                idx = np.argmin(np.abs(arr - tgt))
                ax_t.scatter(interval_sweep2[idx], arr[idx],
                             color=col_m, s=200, zorder=7, marker='*',
                             edgecolors='black', linewidths=0.6)

        ax.set_yscale('linear')
        ax2.set_yscale('linear')
        ax.set_ylabel('AUC/$\\tau$ (ng/mL)', fontsize=18, color=COL_AUC)
        ax2.set_ylabel('C$_{max}$, C$_{min}$ (ng/mL)', fontsize=18, color='#212121')
        ax.tick_params(axis='y', labelcolor=COL_AUC)
        handles_f = [
            Line2D([0],[0], color=COL_AUC,  lw=2.0, ls='-', label='AUC/$\\tau$'),
            Line2D([0],[0], color=COL_CMAX, lw=1.8, ls='-', label='C$_{max}$'),
            Line2D([0],[0], color=COL_CMIN, lw=1.8, ls='-', label='C$_{min}$'),
            Line2D([0],[0], color='gray', marker='*', markersize=10, ls='none',
                   markeredgecolor='black', label='SOC Metrics'),
        ]
    else:
        # Single y-axis with % of SOC
        cavg_pct = data['cavgs'] / ref_cavg * 100
        cmax_pct = data['cmaxs'] / ref_cmax * 100
        cmin_pct = data['cmins'] / ref_cmin * 100

        ax.plot(interval_sweep2, cavg_pct, '-', color=COL_AUC,  lw=2.0, alpha=0.9)
        ax.plot(interval_sweep2, cmax_pct, '-', color=COL_CMAX, lw=1.8, alpha=0.9)
        ax.plot(interval_sweep2, cmin_pct, '-', color=COL_CMIN, lw=1.8, alpha=0.9)


        ax.axhline(100, color='black', ls='--', lw=1.2, alpha=0.5)
        ax.set_ylabel('% of SOC', fontsize=18)
        handles_f = [
            Line2D([0],[0], color=COL_AUC,  lw=2.0, ls='-', label='AUC/$\\tau$'),
            Line2D([0],[0], color=COL_CMAX, lw=1.8, ls='-', label='C$_{max}$'),
            Line2D([0],[0], color=COL_CMIN, lw=1.8, ls='-', label='C$_{min}$'),
        ]

    ax.set_title(f'{label}', fontsize=18, fontweight='bold')
    ax.set_xlabel('Dosing Interval (h)', fontsize=18)
    ax.set_xlim(*xlims_by_label_freq[label])
    if label == 'Average':
        ax.set_ylim(*ylims_freq['Average_left'])
        ax2.set_ylim(*ylims_freq['Average_right'])
    else:
        ax.set_ylim(*ylims_freq[label])
    ax.legend(handles=handles_f, fontsize=12, loc='upper right', framealpha=0.9)

plt.tight_layout()
out_f_sub = ('/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/'
             'Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/'
             'Fig2B.pdf')
#fig_f_sub.savefig(out_f_sub, dpi=300, bbox_inches='tight')
print(f'✓ Saved: {out_f_sub}')
plt.show()

# %%
# =========================================================================
# Section 16: Per-metabolizer frequency sweep — individual subplot figures
# Save each subplot at exactly the size it appears in the combined figure
# =========================================================================
fig_f_sub.canvas.draw()
renderer_f = fig_f_sub.canvas.get_renderer()

for ax, label in zip(axes_f_sub, results_freq.keys()):
    out_f_ind = '/Users/80031987/Desktop/Basanta_Marusyk_Lab_2026/Lorlatinib_Human_PKProject_30Jan2025/Hybrid_Model/Figures/' + f'Fig2B_{label}.pdf'
    extent = ax.get_tightbbox(renderer_f).transformed(
        fig_f_sub.dpi_scale_trans.inverted()
    )
    fig_f_sub.savefig(out_f_ind, bbox_inches=extent, dpi=300)
    print(f'\u2713 Saved: {out_f_ind}')

# %% [markdown]
# Yes, exactly. Raw AUC per interval is frequency-dependent — if you dose every
#   12h instead of every 24h, each interval's AUC is half as large, even if the
#   total daily drug exposure is identical. This makes cross-frequency comparisons
#    misleading.
#
#   Dividing by τ converts AUC into an average concentration, which is
#   frequency-agnostic:
#
#   Cavg = AUC_f / τ = dose / (CL × τ) × (1/τ) ...
#
#   More intuitively: a patient dosed 50 mg Q12h vs 100 mg Q24h receives the same
#   total daily dose. Their raw AUC_f values differ (smaller per interval for
#   Q12h), but their Cavg values are equal — correctly reflecting that
#   time-averaged exposure is the same.
#
#   This is why your frequency sweep uses Cavg_f on the y-axis rather than AUC_f.
#   It lets you ask: "across all these different intervals, which ones deliver the
#    same average drug exposure as SOC?" — a question that raw AUC can't answer
#   fairly.
